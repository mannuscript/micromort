# %%
import pandas as pd
import requests
import urllib.parse
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np

# %% [markdown]
# ### Get the tweets
# filters used:
#
# SELECT text FROM rpmdb.rpm_tweets where
#
# in_retweet_to_status_id is NULL and
#
# in_reply_to_status_id is NULL and
#
# quoted_status_id is NULL and
#
# source like "twitter web client" and
#
# text not like "%http%" and
#
# lang = "en";

# %%
fileName = "./tweet.dump"
original_tweets = [ line.strip() for line in open(fileName).readlines() ]

# %%
len(original_tweets), original_tweets[:10]
# Out:
# (21677,
#  ["am i finally using my laptop for late night anime and not editing or whatever nonsense :')",
#   'i love antarc',
#   "Ohh it's March 1",
#   'Silent prayers all the time for her to be healthy joyous so please get well soon',
#   '18 but heh no difference.',
#   'hi tlist what do you do or say after you swipe right',
#   'LRT custom fe cipher playmats uuuuhgghghh soooooo cute',
#   'cara too talented to just be a model ;;;;;;;;',
#   'Sigh what is this feeling',
#   'god the ost for the lunarites is so pretty but fuck those bitches'])

# %% [markdown]
# ### Clean the tweets using andromeda API

# %%
level = 1
classes = [10, 71] #alphanumeric and hashtags
min_word_len = 5 #inclusive

# %%
def preprocess_text(str):
   r = requests.get("http://172.29.33.45:8000/textpreprocessor/{}?text={}".format(level, urllib.parse.quote_plus(str)))
   return r.json()

# %%
cleaned_tweets = []
for tweet in original_tweets:
    clean_json = preprocess_text(tweet)
    _str = ""
    for token in clean_json['token_list']:
       if token["core"]["class"] in [10]:
            _str += token["core"]["token"] + " "
    _str = _str.strip()
    if len(_str.split(" ")) >= min_word_len :
        cleaned_tweets.append(_str)

# %%
len(cleaned_tweets)
# Out:
# 18811

# %% [markdown]
# ### Preprocessing the text:

# %%
nltk_stopwords = list(stopwords.words('english'))
def lemmatize_token_list(lemmatizer, token_list):
    pos_tag_list = pos_tag(token_list)
    for idx, (token, tag) in enumerate(pos_tag_list):
        tag_simple = tag[0].lower() # Converts, e.g., "VBD" to "c"
        if tag_simple in ['n', 'v', 'j']:
            word_type = tag_simple.replace('j', 'a') 
        else:
            word_type = 'n'
        lemmatized_token = lemmatizer.lemmatize(token, pos=word_type)
        token_list[idx] = lemmatized_token
    return token_list
def preprocess_text(s, tokenizer=None, remove_stopwords=True, remove_punctuation=True, 
                    stemmer=None, lemmatizer=None, lowercase=True, return_type='str'):
    # Throw an error if both stemmer and lemmatizer are not None
    if stemmer is not None and lemmatizer is not None:
         raise ValueError("Stemmer and Lemmatizer cannot both be not None!")
    
    # Tokenization either with default tokenizer or user-specified tokenizer
    if tokenizer is None:
        token_list = word_tokenize(s)
    else:
        token_list = tokenizer.tokenize(s)

    # Stem or lemmatize if needed
    if lemmatizer is not None:
        token_list = lemmatize_token_list(lemmatizer, token_list)
    elif stemmer is not None:
        token_list = stem_token_list(stemmer, token_list)
    
    # Convert all tokens to lowercase if need
    if lowercase:
        token_list = [ token.lower() for token in token_list ]
    
    # Remove all stopwords if needed
    if remove_stopwords:
        token_list = [ token for token in token_list if not token in nltk_stopwords ]
        
    # Remove all punctuation marks if needed (note: also converts, e.g, "Mr." to "Mr")
    if remove_punctuation:
        token_list = [ ''.join(c for c in s if c not in string.punctuation) for s in token_list ]
        token_list = [ token for token in token_list if len(token) > 0 ] # Remove "empty" tokens
    
    if return_type == 'list':
        return token_list
    elif return_type == 'set':
        return set(token_list)
    else:
        return ' '.join(token_list)

# %%
processed_tweets = []
for tweet in cleaned_tweets:
    #processed_documents[idx] = preprocess_text(doc)
    #processed_documents[idx] = preprocess_text(doc, stemmer=porter_stemmer)
    processed_tweets.append(preprocess_text(tweet, lemmatizer=WordNetLemmatizer()))

# %%
reduced_processed_tweets = [tweet for tweet in processed_tweets if len(tweet.split(" ")) > min_word_len]

# %%
len(reduced_processed_tweets)
# Out:
# 12754

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf_model = tfidf_vectorizer.fit_transform(reduced_processed_tweets)

# %% [markdown]
# ### K-means clustering

# %%
num_clusters = int(len(reduced_processed_tweets)/10)

# %%
km_model = KMeans(n_clusters=num_clusters)
km_model.fit(tfidf_model)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=1275, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
np.unique(km_model.labels_).shape
# Out:
# (1275,)

# %%
clusters = {}


for idx, label in enumerate(km_model.labels_):
    if label in clusters:
        clusters[label].append(reduced_processed_tweets[idx])
    else:
        clusters[label] = [reduced_processed_tweets[idx]]

# %%
clusters
# Out:
# {0: ['60 album srsly fuck break lmao'],
#  1: ['take shower read genius thing spotify take god damn im glad put song b mix whim'],
#  2: ['feel like part soul love since beginning everything',
#   'feel like part soul love since beginning everything'],
#  3: ['seriously s way much happen one episode grancrest senki',
#   'kind romance siluca theo happen grancrest senki episode hint kinda blue tbh',
#   'oh man episode grancrest senki damn son',
#   'grancrest senki go batshit crazy episode lol',
#   'ah man nt know late episode grancrest senki recap episode'],
#  4: ['s reason leave first place nt change since month ago'],
#  5: ['really low tolerance someone evade personal time think s ca nt r'],
#  6: ['try multitask watch drama draw narimiya appear completely stop drawing lol'],
#  7: ['dont want bird feel caged hence decide set free even though fledgling hope reunite w family'],
#  8: ['april august gon na good month'],
#  9: ['pato oward stop track lead wow'],
#  10: ['new profile pic tho look like true god'],
#  11: ['show singapore would totally make year'],
#  12: ['brainless resonant nasal annoyance work help'],
#  13: ['nt already feel good happen go put anyone s shit',
#   'whatever shit happen must still look good hahaha'],
#  14: ['nt get people ask permission take item nt way around'],
#  15: ['would draw irl revolver nt fact nt able give art like month',
#   'feel le likely vomit everywhere want field test draw stuff next commission',
#   'haha go draw full colour comic fun want die',
#   'im sure s easy way plaid m masochist hand draw plaid',
#   'draw big kitty cat s edits',
#   's tough bos also distant relative draw boundary',
#   'draw hayato think ah s really cute',
#   'envy people write draw well like someone half bake cant really anything well',
#   'wrong way draw unless draw shit like thou apit cmic',
#   'want make souza hi underestimate inability draw men',
#   'grazie roma right radio tell roma go head hold high come draw heroic result',
#   'want draw nt know draw essay ughhh s short essay ughhhh',
#   'get salty draw character dont get say card im look ssr tsubasa ssr hayato',
#   'sometimes remember bkub sensei also draw comic enstars enstars anime adapts',
#   'm wenger d resign today even arsenal draw lol',
#   'think arsene sack matter result brighton even leave late draw death',
#   'draw chibi face hard need right amount squish squish',
#   'fuck ok realise didnt draw fringe centre lol',
#   'smalling v salah shudders base comeback performance might get draw',
#   'yo draw danny wear crop top lot walao dsjflkajdlk',
#   'idk ppl get problem draw side profile mean need draw half face half',
#   'casemiro king shit housery man nt talented enough beat press passing dribble draw foul',
#   'draw thing hxj basically walk poker card',
#   'opens gw2 later oh im overwhelm urge draw rui',
#   'nyway nap first continue draw ive work commission dkfjgfdg sketch gay shit',
#   'want kind person muscle memory draw fav character',
#   'also random feel draw haruna hair turn decent',
#   'never know big draw whenever m make pv draw regret later',
#   'complain style generic also continue draw say generic style',
#   'maybe ll draw together march s healer showcase',
#   'spend whole day marathoning jessica jones draw stuff guess good way spend sunday',
#   'heck watch bloody monday year ago even draw j fanart wtf cry narimiya s j good',
#   'wan na draw nt know draw',
#   'want continue draw pokemon photo feel tire rather lose motivation owe people draw',
#   'ca nt force continue draw feeling draw',
#   'im fake fan dont think ll draw anything day',
#   'mfw show ppl use draw karkat vantas jus see know',
#   'barcelona v roma tell madrid get easy draw cules',
#   'll draw pochi tama next week',
#   'gitgud ill draw chp 18b d really great exercise draw emotion',
#   'cant beat japanese dragon ball cause draw anime hahaha jesus christ',
#   'wow feel like draw knight demon ocs oh',
#   'draw one half body ryoken wrist start hurt art blog go stay dead longer',
#   'im man chong s draw like fking finally ll double checking',
#   'put poster ask feedback get back cover badly draw dick idea expect',
#   'penalty singapore shawal draw foul ali samooh neat turn box',
#   'think probably start draw sketch edits research moar werewolf',
#   'ok page gesture draw sketch pose ppl brooklyn watch im go home dinner',
#   'time spend animation actually draw frame watch stuff loop',
#   'im sometimes scar draw oc look like percy s like make man would explode',
#   'hey u draw see yeah ok sasuke naruto look like tiny yr fist clench ready fight',
#   'tip advice try draw human anatomy gesture',
#   'like want draw doki doki lucisan hand sli p',
#   'nothing like draw grow men cramp box',
#   'one day m feel lazy guy draw japanese flag teehee',
#   'll properly draw later since something else 3',
#   'aussies stand rabada co match head draw yawnnnn',
#   'dont know draw line cynicism intuition constantly guilt trip think ifs'],
#  16: ['feel terrify see season finale like week like state fandom show well'],
#  17: ['okay nevermind week break guess time catch show find part time job'],
#  18: ['lot feel listen music early adolescence year particularly emo punk song omg s decade'],
#  19: ['march start really well new music soon'],
#  20: ['love something give love s something keep s maze haze complicate sweet never know leave'],
#  21: ['go back home long day eat takoyaki listen mamamoo life good',
#   'go back home long day eat takoyaki listen life good'],
#  22: ['thinking two online friend use talk emailpal correct term one twitter pal'],
#  23: ['love love im sorry im late smh busy run mouth'],
#  24: ['ok bye dinner finish presentation tomorrow morning'],
#  25: ['want use quintuplet septuplets song rhythm game typically nt support 20ths 28th note'],
#  26: ['bemoan u get subspace emissary every day life'],
#  27: ['god bless moment group restaurants opening ooma greenhills best news 2018',
#   'guess ll never group like first one ever',
#   'celeb five best girl group contest',
#   'omg im enjoy ep kwangsoo s group jongkook s group know comedian jaesuk s group mehh',
#   'tbh dreamcatcher favourite kpop group concept best relate girl essentially reality nightmare',
#   'kickoff jalan besar win world good group f',
#   'girl group stan culture become curling fan february 2018',
#   'love mv dont look like usual kpop girl group mv',
#   'want get back actual group haiz',
#   'somebody ban group essay s absolute bad',
#   'many group split recently get notebook put everything tgt',
#   'jung eunwoo queen good taste girl group',
#   'kpop boygroups much reliant sex appeal girl group tbh',
#   'well draw kpop girl group re technically non art interest girl group well',
#   'ca nt boy group instead least know boy group girl group lol'],
#  28: ['know m fucking tired fuck everything'],
#  29: ['dont tell theyre gon na play hooks titles fuck fuck fuck',
#   'm fuck brain dead rn fuck gon na',
#   'fuck bears fuck fuck fuck fuckkkkkkkkkkkkk fuckkkkkkkkkkkkkkkkkkkkkkkk fuckkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk'],
#  30: ['happy birthday hope amazing day deserve love u sm x',
#   'happy birthday hope amazing day deserve',
#   'happy birthday good boy deserve love 33',
#   'happy birthday hope re lovely day deserve x',
#   'happy birthday hope amazing day x',
#   'happy borthday tei hope really awesome great day deserve 3',
#   'happy birthday memossss love hope special day amazing'],
#  31: ['next person come urgent request today definitely feel urgency wrath',
#   'inspire today thanks boo aahah s time get famous',
#   'today like end nt turn angst',
#   'plan cancel today s hoseok s day',
#   'one day left re coming sg today',
#   'retweet picture baekhyun suho s musical today feel op s camera nt distance',
#   'today like game jam drive think quite abit',
#   'everyone worst ever arsenal game carabao cup final arsenal today hold beer',
#   '6 today tmr springtime ll miss snow',
#   'mum get angry today cause bough bubble tea bubble tea',
#   'si oh look cousin get marry today si care s chris martin s birthday today',
#   'oh s hara oppa wed today',
#   'imagine exo monstax fan rip wallet time today',
#   'explosive emotion cry pig today s episode hwayugi',
#   'feel damn sian today must weather temperature affect mood',
#   'mcm get swindle police bukit batok today',
#   'man today s ladder full antiwarlock go winrate switch kingsbane mill rogue lmao',
#   'criterion v criterion thing criterias oh dear never know today maybe',
#   'ive asleep least today headache idk exist',
#   'icon next hashtag best thing s happen today',
#   'last exam tmr procrastinate entire day ytd get ta push like crazy today',
#   'today cover reveal starfang trilogy uk timing',
#   'well make today productive yesterday least',
#   'yesterday history tomorrow mystery today gift call present bil keane',
#   'yotd event still go total mayhem today s arcade mode acrade reset going ham last min loot boxes',
#   'nope nope nope today day play cs fk shit unlucky keep get headshot others',
#   'since s today female icon look',
#   'ahhhhh plan watch padman today seem suddenly end run',
#   'eh hope taka great day wherever today',
#   'ezbuy get mehhhh send taobao order tues s friday today still nt order yet',
#   'sad duty inform eva peron spiritual leader nation enter immortality today',
#   'today doff cap demarco murray gent baller',
#   'good achievement today rank legend na',
#   'want go botanic today shoot watch perform manu priority',
#   'today give time twitter ask anything',
#   'kroos average today zizou go seem',
#   'thought today rest nooooo two video edits backend admin nonsense',
#   'oh man s beautiful giornos tl today',
#   'haiyaaa stock order alone ah today',
#   'mcdonald s chocolate breakfast today re go cheat might well go extra mile',
#   'listening going gold shed seven today nt know choose leave friday still great',
#   'life knock demon try take today hit m survivor warrior',
#   'literal fight md soosh lunch today attract girl sit table library',
#   'humanity trip fell scrap knee today mourn lost great scientific mind',
#   'ppl think leave like tmr maybe fly today',
#   'day prof decide call today today functioning',
#   'today learn channel drag queen watch wrestle life make thanks kris',
#   'le baru kol time pas slowly today',
#   'saw pasar malam fuckin spaghetti donut stall nt buy today tomorrow take part monstrous debauchery',
#   'pak jan late class today phone stick indonesian time lol',
#   'si promise would go jog today wonder s rain heavily',
#   'seem like changwook go watch musical today guess enjoy vacation',
#   'side note finally finish shoot embarrassing shoot today ca nt never forget stare laughter today',
#   'straight people nt allow make comment inherently gay lifestyle thats hot take today',
#   'm take module regard community try deconstruct potrayals malay today past quite pen',
#   'yall today handwrite analyst analyse handwriting guess personality nailed',
#   'today last day huh way forward even cliff ahead',
#   'thousand word finish tmr yet refuse start today wan na blog today heh',
#   'realise leave today plan leave like last night',
#   'today weird british bos ask smell something burn hahaha hinahabol ba ako ng apoy today',
#   'spend whole afternoon make lunch might well eat early dinner instead cook chicken n potato today v',
#   'today definitely gf s act cute day asking wear school shit',
#   'today annoying day like cant handle place kanghionsness s whole new level school',
#   'tf brigitte hours til tmr supposed available today',
#   'official confirm putin phone call today detail yet prior readout',
#   'need get today start spamming guy stupid idea run head',
#   'happy learn kid bully playground today couple jealous kid human like',
#   'today fuck everything chill day nt one since forever',
#   'bought dvd writer dvdrw today felt ancient outdated',
#   'nt know happen today m fujioshi mode',
#   'today beginning spring tomorrow beginning democracy',
#   'camera love june many solo shot today',
#   'twitter personality wellloved friend alike celebrates tie knot today',
#   'wake today feel stress submit project today lot feel much good',
#   'pulled muscle today try watch back',
#   '5 day diet plan start today hahhaha',
#   'today s day nt think anything today',
#   'us gunmaker today file chapter bankruptcy accord court record delaware',
#   'join u today ntsasia consortium annual conference resilience face disruptions',
#   'powerful question carroll thomas g nt nthe schools today would ncreate schools today',
#   'submitted project today 30days payment plan',
#   'today lola find photo u together trip old young remember',
#   'today s pottery class episode cute',
#   'ooh learn new body part today pars interarticularis hahaha sound cool',
#   'thinking would possible finding track datasets easy find article today',
#   'look like teaser arent thing drop today lmao gpa drop lol',
#   'imma go edit video today opens minecraft',
#   'today learn sg mcspicy spiciest region huh',
#   'curiosity today s stream guy want',
#   'shit family today s definitely one fuck day',
#   'swancon start today feeling sad could nt attend wonderful con see meet awesome people',
#   'today s stream take back old school go win try harding see 7pm sgt 12pm cet',
#   'today s one day m feel anything',
#   'heck think undead event today class event starts fk',
#   'convert tensorflow model python javascript today pip install tensorflowjs',
#   'happiness think today sunday realise s still saturday',
#   'erm bad internet speed self declare today day',
#   'oh wow early day many wider easter egg today dope',
#   'alexis jesse good today one quick touch lovely'],
#  32: ['miss cosplaying time money effort another one next event lies down'],
#  33: ['nt know s easy always find something annoy reply s instagram story'],
#  34: ['hi thanks follow look forward tweet',
#   'sabrina post photo write met paris au rilaya nt make rule follow',
#   'pa follow back kuyaaaa rowell advance gift tomorrow lang fo thankyouuuuuu',
#   'every time tweet mine blow people terrible take appear mention seldom follow back ft account',
#   'sam nunberg phone live follow chat',
#   'justin passionate give u follow help spread word',
#   'hey ever want model company follow ill dm info',
#   'nt realise nt follow back bad w',
#   'would mind follow offer money20 20 interview might interest send dm',
#   'hi thanks follow look forward tweet',
#   'would like thank follow true honor follow thank artist michael k schroyer',
#   'world s leading social trading network join receive 20 free follow journey',
#   'follow u first know people run account twin',
#   'ask goal im poly n start cry bawl follow relatable content',
#   'thanks follow love art s always nice local artist look',
#   'weird get upset irl come twitter follow bunch kyungsoo account haha always make feel better tho',
#   'btw thanks write excellent blog follow since beginning really enjoy read',
#   'still believe executive director follow instagram like even friends nt',
#   'im happy follow lu jacks bye',
#   'hello puddytan thanks follow u see ax maybe',
#   'woah person hara follow insta kara twice fan lucky',
#   'woah person hara follow insta kara twice fan lucky',
#   'mmmmmm fic make realise danny s p firm yeah come brett follow',
#   'wouldnt anyone follow chick insta hahhah',
#   'think m go follow deokrim s style asdfghjkl',
#   'hi would kind enough follow dm question ask',
#   'follow cryptocurrency market would buy eth',
#   'tbh m sure follow wrestle instagram account tweet retweet lol 3 keep',
#   'creature ritual deserve friggin cult follow genuinely wtf yoooooo',
#   'follow bbc earth one best thing ve ever human lol',
#   'wow taka s rap scream follow ending story give much fkin feel wow man',
#   'hi miss much thanks follow since',
#   'whao s awesome see interact actively fan ll sweet follow back',
#   'trend follow data leak involve cambridge analytica',
#   'follow whole bunch related account rn pls send recommendation way',
#   'instagram suddenly make follow random account wtf didnt even allow third party apps',
#   're move please follow u thank follow u',
#   'must stop follow hypebeast insta twitter account addictive look em beautiful sneaker wna get errything',
#   'hi could follow back dm niall horan ticket sell highly interested thanks',
#   'find qinfen s instagram hyunsik btob follow',
#   'since guy ask youtubers follow video',
#   'feel well never follow family go eat',
#   'could see follow twitter follow back xoxo',
#   'show something worth look might follow',
#   'wow slick rid thanks follow back',
#   'finally time sit follow email tomorrow yay',
#   'cramp hit think depression follow soon',
#   'visit new updated look blog follow u social medium well',
#   'ive confuse porksterr manager bambam mark follow',
#   'hm cousin try beat year ago follow instagram yeah fuck bye',
#   'create chance study well theres mood follow',
#   'follow recently m honoured u decide follow rtspamming nt say much soft fan like',
#   'delete link since think one follow would read',
#   'welcome thanks follow hope get lot value look learn great day',
#   'omg tommy follow back guess shake grave',
#   'anyone top notch crypto blockchain group worth follow could send detail please cc'],
#  35: ['start sell small work fiverr make real quick money well order'],
#  36: ['loss uhhhh bad expect lot bad'],
#  37: ['lose nt get match time join 205live'],
#  38: ['mothers hold child s hand short heart forever'],
#  39: ['enemy really really good totally ca nt wait love dead 3',
#   'honey take sec reply name rsvp really call friend',
#   'wow people really master art humble brag huh',
#   'random lady ask look tired appreciate really need kindess',
#   'lol medicine eat really give coma',
#   'recently nct doyoung taeil monsta x wonho shownu minhyuk really catch attention teehee',
#   'tried piloxing first time physical training session hour ago really intense workout',
#   'wow daydream sound really mellow think ll funk sound track come hobi',
#   'omg really really love hobi s mixtape fucking psychedelic',
#   'really want preorder michelle obama s becoming gdi 25',
#   'hoseok really beat greatest showman legend',
#   'hoseok really wear 770 fendi slide daydream mv lmao',
#   'guardian angel red jumpsuit apparatus come im actually really emo',
#   'lao ban really like ripped jean ah',
#   'really want drop simu cant lols',
#   'ugh really want adopt sphynx cat love naked baby',
#   'korean drama mother really amaze cast good highly recommend everyone watch nt',
#   'really monstax bois look really good handsome better real life',
#   'yeri annoy gay s attach really proud kiss bring every conversation',
#   'really miss old day hallyu wave',
#   'melo really trash bad thing think s still legit',
#   'nt business whatsoever say confident jessie j really good human s great',
#   'wow presentation politically charge really hope lecturer nt pap supporter',
#   'really nothing junhyeok s fan meeting',
#   'hella triggered new junkrat ult really completely useless slow anything',
#   'great fear failure success thing life nt really matter u',
#   'internalized racism thing really blow away confused',
#   'spurs vs man c really worth 45 ahhhhhh',
#   'pretend sophisticated m really garbage wahahaha',
#   'hyori homestay really heal weekly energy pill',
#   'vgc team look really really random',
#   'watch romcom s actually really good',
#   'romelu lukaku really remind mbaku jabari tribe glory hanuman',
#   'beast really angry artwork attacking hateful liar',
#   'd really like sit someone complete silence',
#   'would like publicly apologize hour late really good late',
#   'really need busted leg heal man',
#   'idk really hope macbook repair spot go appointment apple store tmr minor issue',
#   'chasing pavement worthless s really chase damn',
#   'miss avi m really like ptx s new member matt unique sound approve 3',
#   'never really think d learn c m glad nt fill brain as3 as2 obsolete',
#   'insistence take car school really drive nut',
#   'really nt want order since always go bedok mall bust leg shit',
#   'korean entertainer really best creativity world xd',
#   'damnnn ian really delete dance video megan want rewatch em',
#   'm really curious edit whole bunch mess re go sub mess lol',
#   'im really really really determine redo thread tonight hope ll lol',
#   'school project really pump couple idea mind',
#   'really productive day mind tire think thinking might take really easy tonight',
#   'really nt want go school tomorrow',
#   'want funny light drama watch really recommend laughter waikiki s really mental lol',
#   'jackson really know shake butt im scar',
#   'really someone prioritize look first would lot prettier handsome friend',
#   'use think fake boyfriend au much guess really need fake boyfriend',
#   'scroll tl emotional m get s really back bij kim wooseok back',
#   'li syaoran martial artist swordsman hong kong sound really familiar wonder',
#   'thomas edison really thief thiefmas ediscoundrel',
#   'write scholarship essay answer really remind still get take write something really good get',
#   'like fell show year get back space arc seem really interesting fitzsimmons got married',
#   'lmao dohwan troll really love dohwan x sooyoung interactions omgggg',
#   'really need chocolate peanut cheese apam balik yesterday',
#   'fugggg really miss watch narimiya act show sob',
#   'cough really want geeves smash though imagine final smash',
#   'yesterday go buy umbrage salesperson really snooty take',
#   'really interested quite frankly little annoyed excitement meh',
#   'actually really like boat quay x',
#   'p thanks awesome session melbourne 1st march really inspire build creation',
#   'think chore mundane really one force',
#   'wendy really look seulgi iam crack',
#   'yall sachets owl coffee really stronk im still awake still sleepy halp',
#   'nt really want see undertaker slug wrestlemania',
#   'touch good im yelling nct really pulled soft concept',
#   'really sad im working father s birthday friday z',
#   'im glad actually choose cut tie avoid drama really need old already energy deal thing thanks',
#   'theyre talking female characters persuaders one important plot usually really great yeeeeee',
#   'really got ta make persuader fashion art zine include brett s massive leather coat',
#   'ever series really influence story first time power rangers space hand',
#   'really really hope s worth wait tho',
#   'discord really really really really really really really really ankle',
#   'sch student lounge really arcade machine',
#   'really need remember extinguish scented candle room head',
#   'existence pi curiously hint universe accident something really divine circle cycle',
#   'really really really really love dance okay maybe end lil uncalled generally s goooooooooooooooooood',
#   'vrains spoilers we really fight line broke',
#   'every time see mvp think really ought minimally minimum',
#   'nothing finished korean odyssey wow really trash',
#   'lel minsoo s end part candy land come sigh deeply like boi really',
#   'really need learn take thing slow sometimes',
#   'renjun s korean really really really good d think korean',
#   'im really convinced john mulaney bo burnham real like one earth comically self aware',
#   'wataru really freaking funny comprehend looks cool s loser',
#   'm listen v iptenchou s cover oh man really miss',
#   'oh god really really like wataru hahahhahahaa',
#   'tbh gbf never really lot fan writer idk much lore',
#   'decide thing base influence high control really decision',
#   'yunho look like lose weight gain changmin must ve really nag',
#   'feel bad come twitter im upset really need outlet vent might implode',
#   'really hope exo get rest deserve',
#   'need 30th arrive asap really needa crawl hotel bed friend talk emotion feel eat maggie mee',
#   'always sense insecurity ive find really trouble time like',
#   'alright day really miss shitting home',
#   'missing favourite aries hope re really happy please come ok',
#   'woah really push romance siluca theo huh',
#   'able intensely fangirl something like tv show artist someone really like deserve',
#   '401 really best supper place around area sia meekia soooooo goooooood',
#   'omg yuehua really rich kid zzt wear gucci head toe lmao get money',
#   'outfit combo flo look really familar idk s show another show',
#   'browse crunchyroll decide go one room finish episode interesting nt really know huh',
#   'feel well yet recovery really go downhill',
#   'yook jidam girlie really another level sia ownself start shit want people apologize action uhhummuhhmmm',
#   'hyung really re really good make someone fluster',
#   'really nt fault though poor tanya',
#   'ok really need right supercut newsreader say count dankula really solemn voice',
#   'm go go take break m sorry m really really tire',
#   'human psychology maybe really consider take kind module minor winter school',
#   'really close twitter phone open twitter computer',
#   'watching hitler documentary hear mark narrator end really interesting',
#   'show get really bore almost everyone stupid season 2',
#   'haha kid really ask lot exercise diet regime one thing surprise never cardio',
#   'watch siccin honestly really scary way makeup effect ghost damn gooood',
#   'really want stand front guy one bss',
#   'tiring day feeling unwell recover sickness really sap energy',
#   'nt really energy write today someone recommend long fic read pls kaisoo chansoo sesoo baeksoo etc fine',
#   'm really glad catch hakata tonkotsu ramens s enjoyable show',
#   'thinking redecorate apartment really small need intelligent designer suggestion',
#   'm person really call mata catch fuck boy toot horn nonstop car road show mall',
#   'm currently phase need watch worth stimulate appetite eat really happen rn',
#   'idk kinda like really hope save enough go trip time want keep little save saving',
#   'really need hire skystar s va tv series screw money need skystar',
#   'best feeling ever get home lolita meet take petticoat really invest hoopskirt',
#   'honestly ns really drain away social life',
#   'jungwoo fucking cute really bring uwu',
#   's really cute korean friend keep talk japanese ling dang bday',
#   'skin really dry body shop moisturiser nt strong enough aesop s expensive sobs',
#   'sighs next time really think twice order good china shipping fee really expensive sob',
#   'arctic monkey really set mood well',
#   'drop groove chip along edge m really upset',
#   's really painful shoot cramp thigh m weep terrible need ice pack',
#   'ohmyy budapest opera house close really want go tmr',
#   'alright think look really good see artwork shit',
#   'really hope win g see katy totally deserve',
#   'gosh m tired term really take toll',
#   'god bangtan really collectively bad everything',
#   'first 5min literally piak piak piak guess really like slap clay wonder slap',
#   'a way gameplay look really boring',
#   'miss see happy angry tbh like really angry like outburst flo',
#   'former trainee see really close englishspeaking idol e shannon sorn mark jae aron nuest hmmm',
#   'clout money really get anywhere huh',
#   'feeling really upset mood remainder day totally ruin',
#   'anime really peak entertainment congrats japan',
#   'thread omg really look sweet cute together good father',
#   'legit nt really know react get slay mv style song everything sob',
#   'say best place hide tree forest really big tea cosy suffice pinch',
#   'really s tell true really make day',
#   'also want say another person cuz like fking nice fking friendly nvr really assist much oh weelll',
#   'tbh nt really like shirt wallet look like go burst haaaa',
#   'im scream theyre really personal clown jeon jungkook perform middle kbbq restaurant',
#   'internet slow issue living sixth avenue connection really bad even 5g',
#   'm finally home another nighter school surprisingly nt really feel sleepy know m tired ironic',
#   'flowers bloom early tokyo year really hope nt miss re next week',
#   'm glad start play mousehunt disappointment get miss row really miss life',
#   'synnara s estiminated weight replay 5kg hope s really light lol',
#   'spent time mum chill sofa together probably know m really stress',
#   'tae really n bomb im wheezing',
#   'today s episode lighthearted m laugh time really enjoy lot',
#   'jolin tsai advice trainee really admire',
#   'tbh part hnk felt really really draggy reach part relationship s painful',
#   'oh man really need get farcry s 70 though',
#   'piece medium relation tony overprice really worth much man',
#   'guess ll make song since nt really want invest earth really water',
#   'love nerd get excite find good material supplement academic paper m really interested write',
#   'sure whenever weather extremely hot like today get flu really bad runny nose',
#   'rance really emphasise rance s role saviour world huh prologue bad end make sleep long pretty bad',
#   'really hope madhouse invest ngnl s2 w s year never late season 2',
#   'lol really think film cf banana milk',
#   's though really friendly buizel friendly chat'],
#  40: ['smile every single night hide feeling im point time wonder still wait'],
#  41: ['hi gerald u know time picnic end tmr cause reach 2pm harry tix go'],
#  42: ['honestly proud progress writer like almost ca nt believe far ve come'],
#  43: ['oh goodness watch svu holler please need talk'],
#  44: ['drink safe enjoy responsibly nt tell'],
#  45: ['need sleep im syncing phone listen otw work tomorrow'],
#  46: ['oh btw find red sparrow tedious good spy movie tv show',
#   'bf s super power watch movie eyelid',
#   'many marvel movie netflix ca nt life remember one ve see re generic',
#   'every time watch cloverfield movie leave even question',
#   'feel like binge watch disney movie',
#   'video press tour favorite part every time jennifer lawrence release new movie s best',
#   's recent rerun old movie channel sundays sundays suppose mean movie premiere reruns',
#   'coco big hero top movie time ahhhhhhh',
#   'im watchin new jumanji movie nt see original m go totally fresh',
#   'woah sheet marvel movie star war force awakens netflix',
#   'damn movie fking legit quote love',
#   'everyone ge m take like oh ve watch movie ve watch movie',
#   '3 exfile return exes n movie seriously comedy quite sad nice movie though',
#   'lrt im glad exact three barbie movie grow love',
#   'im pathetic started crying liang popo movie song',
#   'gna watch ban g movie pulis pls come catch',
#   'movie documentary make think lot make think much headache',
#   'bleach movie kuchiki byakuya cast s quite alot thing cover span one movie',
#   'shit ca nt find sub movie guess ll watch without sub sob',
#   'weekends gon na spend cuddle dog watch movie alone',
#   'anyone wan na watch movie projector',
#   'feel like horror movie night tonight',
#   'realise fob song actually reference movie',
#   'watch tokyo drifter relation fast furious always want see oldschool yakuza movie',
#   'im impress cod ww2 manage fit every single war movie cliche campaign eyerolling bullshit',
#   'digimon tri movie trailer omnimon angel mode something im hyped',
#   'watch along gods two worlds really need lot tissue movie',
#   'like sweet smell success one known tony movie still nt watch',
#   'm piss netflix give u bahubali hindi tamil like wtf original movie telugu',
#   'lol lee kyung kyu quickly respond seem invest thing well thought invest movie',
#   'filler till april remake boruto movie series',
#   'saw fifty shade freed movie wish could experience sort love somehow',
#   'gentle reminder scifi movie fan annihilation netflix',
#   'midterm saturday havent finish study im go movie tomorrow afternoon great priority',
#   'watching postduodecima celebration duodecima movie face hurt smile',
#   'omg s lee chong wei movie',
#   'movie ape best gosh im bored cant sleep zzzz',
#   'time spend watch hey arnold movie worth',
#   'lowkey happy international break finally watch movie weekend night',
#   'everyone nice korean japanese movie recommend please thank',
#   'watch movie without prior knowledge friend s gon na bit horror wait',
#   'help incredible movie one move close tear',
#   'reality show movie tv show mc kibum busy year',
#   'see action movie star someday like gina carano',
#   'ok m watch lucky last movie star late harry dean stanton incredible',
#   'course would love watch movie star pretty little galway girl',
#   'tbh tony jaunty jalopi movie kinda danny wilde look weird war movie',
#   'jimmy s introduction end payday movie lol s fking crazy',
#   'along god seriously good movie cast acting beyond class',
#   'apparently win pair movie ticket pacific rim dunno extra ticket',
#   'cringing old hk movie dad watch plot past cringeworthy yet interest',
#   'pacific rim waste storyline see movie cliche plot twist forced shit movie',
#   '14 movie na download time bilis',
#   'knight shin amour movie would put lip mine love taste',
#   'spend last week binge watch old time favorite movie',
#   'planning inspire rewatch nth time yesterday got ta love movie',
#   'ah man could rave much love mazinger z infinity movie',
#   'start watch avenger movie cuz im intrigue s enough motivation'],
#  47: ['ca nt believe math ia kill m tweet afterlife'],
#  48: ['feel empty feel like concert vlive'],
#  49: ['ordering dollar poh piah good good'],
#  50: ['china commerce ministry say china take possible step protect interest usd dxy cny',
#   'china commerce ministry say china wo nt accept negotiation hijack unilaterally usd dxy cny'],
#  51: ['one rewrite star say ll mine everything keep u apart m one mean find'],
#  52: ['love reaction kind person u wan na keep'],
#  53: ['love jung hoseok trend like hell yes person bless u today incredible masterpiece'],
#  54: ['stop stop brexit world crash burn fault'],
#  55: ['rly die wan g ker comment omg think wake whole fam'],
#  56: ['travel alert french polynesia france papeete avoid protest associate general strike march',
#   'travel alert pakistan lahore avoid protest outside railway headquarters related procession march',
#   'travel alert france paris avoid vicinity us embassy due ongoing unruly protest prokurdish activist',
#   'travel alert mayotte france anticipate disruption socioeconomic protest avoid rally roadblock',
#   'travel alert india delhi anticipate disruption avoid protest lead prominent social activist march'],
#  57: ['anyone link super tv ep raw'],
#  58: ['go watch black panther twice time air lipstick ad time felt attacked'],
#  59: ['play bit age empire felt bit better need get act together',
#   'bit test think cat largely deaf',
#   'went day work day next week hahaha feel like supervisor tell chill bit',
#   'snow white snow drop white snow leopard pale bit go wrong snow pea',
#   'actually m pretty tire would like go sleep hmm shall stay bit text boy',
#   'oh man think might eat slightly uncooked piece meat feeling slightly nauseous stomach s churn bit',
#   'missing washington lot right wish could ve explore seattle bit haha',
#   'twitter bug im gunna use bit',
#   'feel everything nothing emotion tone bit',
#   'feel like puke little bit calculate much money rest month lolol',
#   'thank social medium sift friend great memory dgaf still love every bit',
#   'lose every bit motivation actually finish task lineups meh',
#   'trying concentrate s doofus next table talk bit loudly',
#   'lunchtime begin get bit stressful colleague excited everyday find cook lunch',
#   'wah work like apprentice keep new project stuff bit tire mostly quite fun',
#   'first voddie night always best second bottle usually bit blur',
#   'wah go nt need lol cause alr get pbs bit funny take keyring lol',
#   'bit sleepy m damn awake man s go',
#   'im go take lorezapam travel back time watch old episode daily show john oliver host bit',
#   'ate bit smoked salmon think go bad m neutralise whiskey',
#   'bit scary ridiculous code name like skylake kaby lake enter device name linux',
#   'much jc prepares university im uni repeat jc tiny bit extra stuff',
#   'today remember jc kevin s middle name scott make giggle little bit',
#   'morning still feel bit sleepy today day go remote part singapore east',
#   'believe leena give little bit time',
#   'saw amanchu go second season enjoy quite bit',
#   'watch dean jerry dance bit legs move like wth',
#   'hmm snow get bit thicker beautiful cooold',
#   'amazing bit sad back real life',
#   'around try proud every bit work walt disney',
#   'end point finish line cross continue heal day day bit bit',
#   'dongwan s solo bit jam 1 always kill like dead alive dead back died',
#   'every bit statement deem wrong every bit get right hmm',
#   'stealthy bit didnt enough arrow time get master kohga whatever fuck name',
#   'idk man im bit worried dont get ticket even normal one ll spend hayato merch instead',
#   'really silent bit ornery need shower',
#   's day early start manage sleep bit',
#   'yall fiestar s apple pie sound tiny bit like ca nt tame miley cyrus 90sexid',
#   'damn sleep bit hungry bit tire enough'],
#  60: ['rng make mistake let mlxg play game almost lose series vg idiots',
#   'lrt love snsd s best friend play bg obvious couple',
#   'play women s world championship due lightning',
#   'omg keep giggle arin dan play doa',
#   'im lost whether continue play dw9 kiwami2 watch aibou',
#   'today play mahjong guy throw ball like u want gang honestly never shook life',
#   'keep see horny gbf guy tl pl ease stop dont want play gbf',
#   'really want play ddr tt anyone willing play one day like arcade',
#   'nt help workplace play slow sad chinese pop songs making even sleepy stahp pris',
#   'sign times play yesterday ll damn emo lol',
#   'tfw hobo play one game end one experienced',
#   'play game throne win die n george r r martin game thrones n n',
#   'someone play lee hi breathe opposite block',
#   'return superman even play love scenario legendary song',
#   'least play david luiz middle field instead drinkwater fabregas partnership',
#   'ruff still play nt buy want mint condition lol yah obvs also show actual record lah bodoh',
#   'discover malay band masdo fking play legit pop yeh yeh',
#   'm friend play pokemon s lavendar town loud middle coworker s yoga session',
#   'probably never get good puyotetris nt learn play arcade controller',
#   'time play is ten hearing sound actually sound nt take med',
#   're play liverpool home re struggle break palace ffs',
#   'maybe give city guard honour old trafford lot need play properly',
#   'feelings fade people change stay play game re leave nothing',
#   'hi apple play pause button longer control itunes directly',
#   'class start want play new final fantasy',
#   'every time play rpg always mess skill tree build real life nt exception either',
#   'haehatehaaaaaate possible love interest tension show nt happen liek u play w feeilisngs like',
#   'dark main team full ssr guess play seriously hh',
#   'wife never play boardgames keep destroy new boardgames every night',
#   'eee annoy click youtube vid play previous vid must always refresh sia',
#   'think want play tpp shit bad pubg player would basically like play fortnite',
#   'every idol otome game like play otome idol game much chosen one',
#   'dad buy ps4 play fifa pal',
#   'feels stop playing school team play club',
#   'waste day play age empire kinda addict',
#   'youtube auto play suddenly decide play please nt go',
#   'sob ve learn play keyboard left hand break damn j huge hand',
#   'sulaiman continue onslaught project makeover ben even ask li yan beforehand well play',
#   'syaoran cook play piano good sport fluent english talented swordsman come hong kong',
#   'happen u play much forget lyric bobby',
#   'anybody want play amq m bored need something',
#   'omg want play banluck ve deposit angbaos lol',
#   'im suppose study keep play fgo check tl djgdkjgdkj',
#   'man vika play sloane 2nd match comeback ree play vee draw ffs',
#   'get stick load page time already patch speed byte sec cant play waste vip pas',
#   'least confident ve ever see vg great solo play almost teamwork term get kill selfpresevation',
#   'one play mon 60 card mirror',
#   'back sloane nt know girl play miami yet',
#   'morata higuain costa fkin hell even lukaku play better atm',
#   'stopped play wl since early feb seems like great decision',
#   'm itch comp tonight two day watch owl without play hhngg',
#   'call duty make mad whenever play still play anyway blame',
#   'play throwerwatch nest play im drunk add ps4',
#   'conclusion play ow cause feel existential dread',
#   'love play mesut ozil pes2018 class player',
#   'shall play safe upload screenshots vlives case get suspend',
#   'like play game end one win',
#   'need remember play game play halfway',
#   'mineski look bad worst compies play',
#   'wow actually play good football fucking individual errors cost us hais',
#   'imagine ignoct play dewdrop dawn piano aaaaaaa',
#   'entire gsw roster injure play bad',
#   'play acoustic version always im emo top 20',
#   'play mix kpop eng song cute omg love place sm',
#   'want play politics game ok la play play let s see come top',
#   'also period time defend sc2 friend around play dota gaddam',
#   'love birdie play thanks great game',
#   'planned work get emotional play game distract',
#   'think m addicted monhunt ve play till hand ache 3ds nt remember last time happen',
#   'finish coffee s 3am synth pop play ears im pumped',
#   'game would ve least expected fortnite br game make video game mainstream',
#   'omg play luhan s fire jackson s papillon intro im already verge tear',
#   '2am thought someday really want play drum set',
#   'like since guy quiet play game hmmmmmm guess learn something new time day',
#   'situations like make miss play game',
#   'lukaku 25goals season people talk sanchez score united even yesterday didnt even play',
#   'jake whats ping like fortnite ca nt play game 180ms ping asia server',
#   've least let zappacosta emerson play oh well',
#   'wonder many day play tetri make sick dont want play anymore ever',
#   'ah tennis sport never watch faves play',
#   'packing luggage physical form play tetris',
#   'strangely reward dont play video game first come hello banner saga switch',
#   'aranea gif singlehandedly make want play ffxv',
#   'time binge watch ffxv content play game',
#   'play chinese otome game understand guy works im freaking curious',
#   'autopsy show mark dombroski fell fall height show foul play',
#   'actually think enjoy sc2 lot since nt play rank',
#   'jongin sehun make feel like download game re play lol anyone know game hahahahhaha',
#   'play today set first singaporean ever brb',
#   'gaming pc gta 30 hitman 32 overwatch 26 dead daylight 13 game play every night 0 battlerite',
#   'omg yumi spot try figure korean song play one house',
#   'little girl play sofia grey look believable sara ramirez s daughter actually scar',
#   'jimin play piano violate yoongi culture',
#   'im damn tired play nier still play',
#   'rush play lck best lpl team play one another btw hahaa',
#   'hyped swain hanabi fw also play',
#   'one team play spirit game kumble',
#   'kinda hope brings puzzle fighter steam online play',
#   'wtf game play earlier day japan server didnt even know everyone speak english lul',
#   'max payne one best game ve ever play',
#   'seeing team try play softball hilarious omg',
#   'stay till 3am play new marvel mobile game',
#   'spend money lan next day play maple lol shopping alone boring',
#   'lol pay nintendo switch time get play bayonetta get ta go japan buy game',
#   'guy never even play destiny much oh wait s lul',
#   'cant play uk bluray bc im fucking singapore',
#   'btw someone remind play robomi z bc d probably forget otherwise',
#   'never want c card play sbts damn upgrade c b card goal worst',
#   'idol game enjoyable difficult think play never stay a3',
#   'o2jam forever remain one best game ve play childhood',
#   'well play unlucky shot resemble sachin'],
#  61: ['feel emo ve stanned ever since stop stop'],
#  62: ['left ankle act probably due long hour stand walk'],
#  63: ['uh hello find photo tony manhandle different photo bc rog',
#   'uh hello find photo tony manhandle men different photo bc rog'],
#  64: ['ca nt wait yoseob s solo concert already haha',
#   'ca nt go solar s solo concert saddddddd'],
#  65: ['know hate play like right loved like heart im trine forget'],
#  66: ['ooooh nice see abi daughter squad'],
#  67: ['man end ll gray hair wrinkled face'],
#  68: ['gon na try one time install game give stupid error m even gon na try thanks ms'],
#  69: ['hxj drastars final part tour sing yozora right right'],
#  70: ['thought woman form whisper net woman terrify enough happen ca nt even support one another'],
#  71: ['100copies ve get project idea dm u',
#   'think ve learn way internship project project ve'],
#  72: ['oooooo new love interest next episodee',
#   'love face would new album s name suit',
#   'really love mamamoo s new album'],
#  73: ['support member ll member nct unit soon'],
#  74: ['say want david goh actually know teach',
#   'goh one actually teach like wow'],
#  75: ['preorder bandai h figuarts figure avengers infinity war'],
#  76: ['ccb 5th time finally pass mock test walao ehhh',
#   'time forget parent get old get forgetful must learn patient',
#   'hmm probably time start think proper pc desk chair situation',
#   'want go back time actually understand read first time',
#   'miss time sbp sometimes man haha',
#   'wan na go back time rewatch name silent voice first time',
#   'strongly doubt since m spend time friend upcoming day',
#   'know alien voice sakurai hear many time recognize lmao',
#   'feels fully dedicate everything alone time rest holiday human',
#   'time yearly training class think like go somewhere co cust complain japanese broken understandable',
#   'nt remember pde ode module require time whip ma1506 cheatsheet',
#   'idk many time go production side office lmao',
#   'unable access cimbclicks try many time',
#   'know s bad construction noise karaoke construction time saturday afternoon bloody hell',
#   'mess around full time dreamers less time achieve shit reality yall continue sleep well man',
#   'time wikied list morning d like give credit series reads whole list',
#   'lose couple time make realize difficult win n steffi graf n n',
#   'winner someone get one time knock n author unknown n n',
#   'whatever odds share class long time ago two share birth date',
#   'american ads funny ad medicine spent half s time telling people take',
#   's time taekook shipper go wild',
#   'time despair place selfpity need silence room fear toni morrison',
#   'enter shiva raid punish host prematurely last time',
#   'time watch sandy get vored 3rd time',
#   'thanks keep u company time bid adieu goodnight',
#   'voices distant star netflix time cry',
#   '6 dama time uncap another benedia',
#   'd amaze time flow backwards still time fill cup slowly',
#   'part time mon thurs let s goooo',
#   'present final oscar award best feature nt mess time',
#   'tgok fatonah azali lgi cuz tht time tk concentrate',
#   'oki time get back bungou mayoi hopefully treat better time',
#   'time load ungland aremix nation 14',
#   'cry every time see lucifer x sandalphon save spark gbf reunite 2',
#   'ever since start write nt much time read fanfics lmao',
#   'time figure add blog gatsbyjs site last time fail',
#   'wtf ri ra ng ra dio im fking disappoint time',
#   's hop sedative effect med actually kick time',
#   'cheesy paneer track britney spears baby one time',
#   'time quit income take plunge degree amidst visa uncertainty require panglossian approach',
#   'drinking game time illustrator crash take shot',
#   'think might allergic shower every time shower vomit',
#   'going cancel starhub tv subscription s time',
#   'cracks cold one lays notebook open laptop awwwwwwwright let essay time reads plot incredibles sigh',
#   'feel save 100k topple step target time',
#   're rate limit first time wtf',
#   'najib call selangor bn ensure get defeat third time 14th general election ge14',
#   'feeling wanderlust time go get completely utterly lose somewhere',
#   'many time must spurs learn defeat',
#   'give time misunderstanding reveal foolishness good intention',
#   'time take korean back us trip',
#   'everyone s praying guarantee grandefes www easy spark time',
#   'time m reminded unfair world make yearn justice',
#   'little run bts marathon laptop cuz holiday time begin',
#   'realise many time forget add noun naadj chat',
#   'putting salt rub ur ulcer enjoy thing time painful',
#   'travel time school hour plus fak',
#   'finally fly month s time thrilled totally dread time flight lol',
#   'amazing time spend together lovely time 3',
#   'forget tell yall cant whatsapp time ll around fb twiiter ig dm',
#   'see many fanarters find style become sooooo goooood time',
#   'time guy nt know japanese translate japanese',
# ...
#   'please ces hot cute doggo im dead',
#   'im fly tmr still havent finish oneshot',
#   'im late momoland bboom bboom masterpiece',
#   'prev rt haha explain alot im go also',
#   '1 thats im ask hunny please charge dang im tryna rush text die da crucial part',
#   'im losing shit rn sis like think know happen',
#   'doll clothes shop hongdae boomerang mics outfit im cry',
#   'aaron seb red alert im dead',
#   'anyway ive im go vacation july',
#   'im torn get photobook shit adsfjklahlsgahsl ghka shipping korea address usd2 sg usd22 thisssssss',
#   'liverpool s line sick im scar',
#   'im gift dinner friend force listen aaalfshka',
#   'im sorry im happy right word keep hear dahyun s mouth chaeyoung chaeyoungie i',
#   'hope get p5 merch im tokyo',
#   'first verse chorus im already ded got7',
#   'afternoon till plus im home thanks eh emrrgency department',
#   'ed s japan april harry may niall june im actually miss',
#   'realise im evil sister girl s bf would lmao',
#   'clear zephiel infernal serra lucius im',
#   'im almost comic im busy drown lyon feel send life ring pls',
#   'omg im work spazzing new order even though im one otl',
#   'mom think im rot home im actually stress look good job haiss',
#   'im tired socialize please leave alone',
#   'im cry 24 melon 7 genie 10 soribada 10 bugs 2 mnet 22 naver go',
#   'im emo everyone fact debut 24 melon im cry cry',
#   'keep procastinating dling sims becos thrs much n becos first round fucked im even lazt',
#   'im amazed re well internationally domestically',
#   'hayato give flower dont like flower accept dont cry im happy',
#   'dude im crave girl guide cooky get shit',
#   'im try eat think bird try communicate haseul',
#   'dont even know im wait hahaah im even buy askfuaglsfahlgjdhsg',
#   'ahh im finally back im tired co sleep late last night',
#   'im check game notice nct woah',
#   'im mood make kplaylists anyone listen',
#   'im excited hbdc show colourful dance performance im thrill see offer',
#   'ive thing past two day im start get sian',
#   'im lowkey feeling like soo ho without anyone haha',
#   'hope everyones lunch go great bc im screamin',
#   'like kinda uneven im diggin cuz freaking light color',
#   'im scar dye gna dark lol',
#   'guess im story ride im gon na take break finish today tomorrow',
#   'song cute likely get wt02 early bday present unless forget im distract something else',
#   'tfw tell complete brick seal im farm grimnir',
#   'im pretending like im okay im',
#   'im try clean old twitter put belial init weird',
#   'also im sure im actually ill period get transplant patient get ta paranoid thing',
#   'zhang wei bother fact im still single married hahahahahaha',
#   'find post persuader cap dvd rip im assume bc look kinda terrible im',
#   'tfw im suppose farm rotb farm grimnirs',
#   'whenever im sick everything go downhill damn fast',
#   'whenever im sick everything go downhill',
#   'im crying saw ur new display name oh gogof avocado woudld anything',
#   'comec ou cherry bomb e eu im biggest hit im biggest hit stage',
#   'wow everything turn fault even im something good',
#   'know friendship r fleet sometimes get bum im close anyone online offline',
#   'everyone seem think im rich im local uni pleb rely rp guy watch',
#   'im look forward see love simon theater best friend also cry idk im look forward',
#   'wah idm study im still young lol imagine learn subject yoona',
#   'im die korg s kiwi accent s taika nt',
#   'fandom learn sit lmfao im tired',
#   'aaaaaaaaaa gpa might con hour im terrify',
#   'im loyal loyal circumstance need infinite loyalty',
#   'oh facade rly good im come back indie',
#   'julia im height idk s tall im 154cm julia smol yall way',
#   'also actually finished something im back bit djhfgf im gon na go write',
#   'im im gon na laugh river yusuke',
#   'lapar im lazy eat rice thats sure',
#   'im living miz cracker v aquaria story arc 1 im petty like',
#   'boi im sell sneaker steal someone get em plz',
#   'reality come day day im nervous',
#   'im living next sub stream sunday cant come fast enough',
#   'girl populady go show im shookdt',
#   'time round im knetz s side',
#   'im glad exist ihope u exist life noww',
#   'im definitely get german hunting terrier',
#   'im always tempted crack stupid joke dept whatsapp group',
#   'im tired uzuki event alr please release',
#   'think im actually going bald hahahahahha',
#   'im still mad saffron sharpe isnt jail video',
#   'fk im im gng lear report bye',
#   'thanks game started yakuza im stuck',
#   'brendon s high notes im screaming',
#   'im losing focus brb go hide toilet',
#   'im try get draft thing work tonight im hungry want koi',
#   'james go see motohead young lad im',
#   'mad excite go la nyc n san fran also mostly la cause im basic',
#   'idk salesman mati2 nak dtg office presence like im go buy anything also',
#   'lol navi lose random team oq wtf im sad lose',
#   'literally cancer horoscope ask im cancer',
#   'im gon na research up10tion hahahahs cause im love cansyland zomggg',
#   'im actually kinda glad release news day since im busy work',
#   'lrt oh yeaaaa im ready spend money',
#   'get ta buy primer bad im lazy go store lmao',
#   'im suppose save trip suppose update cousin june',
#   'simple coz im think bout u vise versa',
#   'start make weird noise think im beatboxin jammin friend mute mom stfu kid keep alright',
#   'lol swear im fucking big idiot rn',
#   '12 day teaser day im home start bawling',
#   'im surprise someone forget important date clearly show important someone haha hais',
#   'know alrdy sad like im sad',
#   'im bad font normally im look jp font',
#   'im try write something chinese honestly cant remember write li',
#   'kinda feel sad bc im still revise gpa probably cast stone zzzz',
#   'im go sit next hour digest',
#   'back ache day straight im piss',
#   'im ready last episode touken asdfasdkj',
#   'dahi aku ade talk layan today im tired idw talk any1',
#   'need mid day motivation im go crazy office workload lmao',
#   'im go die im see jong dae tlist',
#   'honestly never ask anything need appreciate im still thats',
#   'also like im upset im gon na get uzuki 10k rank give man terrible hate thi',
#   'im done im done editing exported goodnight',
#   'parent end payin enrolment fee im',
#   'oh think im get feels trapped',
#   'help la im behind article cuz handle hospital stuff im really sian write ahhh',
#   'im screaming dap coming sg 15th sept',
#   'im convince jackson charter plane also teleports place place',
#   'deactivating account cause im w everyone fking give im bye',
#   'damn im tired im legit fuck w everyone im gon na leave bye',
#   'im learn bake red velvet cupcake marshmallo life',
#   'soz im tryna find cap replace playlist cover',
#   'hi im jar im never fuckinfg learnt draw',
#   'hi guy theres bee apartment im hiding',
#   'im fuck sick school im really glad im graduate lol',
#   'kay im late yet yaaassss stray kids aegis',
#   'im nervous know class know result damn',
#   'want pee past half hour im playing gbf emusute time im zone please interrupt',
#   'come australia im cry pls need u come australia',
#   'colleague tell cry yakuza end im like know',
#   'im cackle lecture watch see eliza happen youre bad student skip lecture shitty report',
#   'freak im pretty pack japan trip im tired alsdkgmlasgkmasdf',
#   'im best place right least im',
#   'try spend money lmao im impulsive buyer sometimes bad enough',
#   'im gon na order sushi delivery bc im lazy',
#   'one sad naruto songs started playing im rereading flashback fenhawke maker',
#   'rog wore magnificent cardigan im 333',
#   's im still tad gay tire sad gay',
#   'wah life quite boring ah im home fold laundry listen radio cause band like feature later',
#   'feel like workaholic im even work dont even think im stage feeling suck',
#   'like idol wt02 cruelty im go grind mstars jelly later',
#   'im glad didnt save new aqours set asdfghjkl',
#   'ummmmm jieqiong originally super worldly attractive enough speaks chinese im',
#   'happen living room im scared check',
#   'think im late great showman make cry haha kental hais'],
#  958: ['jackson actually hear airpods omg cry die',
#   'omg jackson twist phone feel die',
#   'omg phone call jackson sound fucking relaxed skjdskjdskdjskds would break'],
#  959: ['darling franxx get lewd every week',
#   'darling darling mummy come laterr yayyyy',
#   'gon na piece pairing recent darling franxx episode',
#   'society see darling franxx seem bit orwellian'],
#  960: ['oh crossingfingers sched change like puhlease',
#   'nt like change re go like irrelevance even le via'],
#  961: ['realize ve work close month ngee ann omg',
#   'realize re feel like s month since ve suffer school'],
#  962: ['talk ashiq family future thing work stuff mum suddenly talk bout ashiq',
#   'exited bout tunang almost everyday talk ashiq bout hahahaha'],
#  963: ['yugyeom s part rght choruslfjhdlfslfl dont talk',
#   'dont talk act dont say show dont promise prove'],
#  964: ['two hour get hear new fickle friend song u kidding',
#   'new fickle friend good want album'],
#  965: ['nt expect hooked onto mamamoo s song good',
#   'asphyxia fucking good song ca nt help m hooked'],
#  966: ['istg unpk need stop screwing brain wtf',
#   'obsessed maashi s nips wtf stop infecting',
#   'eye wo nt stop tear wtf'],
#  967: ['whatsapp message relate work ban work hour'],
#  968: ['try execute abstract idea since nothing',
#   'think make good abstract game would convince buy abstract game'],
#  969: ['omg park shin hye choi tae joon combi something never imagine woah',
#   'yesssaaaa park shin hye choi tae joon naisee really ship couple although unexpected yess'],
#  970: ['nt matter look like long somebody love roald dahl witches',
#   'tried hard get far end nt even matter',
#   'love mean m pretty part m matter n n',
#   'matter hard try thing never like plan',
#   'one know like since re one matter run',
#   'love matter hard day get u'],
#  971: ['idk im watch game way predictable',
#   'honesly idk ve ever see smarter compelling show',
#   'idk ve mention love nekoma le bboys really tie cat swift idk idk',
#   'idk get lev yaku nendoroids since come set ansldjan'],
#  972: ['even guy s job use like kit make one fafner much time keep make'],
#  973: ['nt like anymore pake ko na', 'happy na ko re reason anymore 3'],
#  974: ['cant believe ah still play minecraft wtf',
#   'ever watch ah play minecraft forget much use enjoy'],
#  975: ['ca nt wait spend day tmrw'],
#  976: ['keep habit whatever even timecrunched feel unduly tired take day',
#   '4 day go mannn feel tired'],
#  977: ['courage live bring reward n rachel l schade silent kingdom n n',
#   'd never know could feel broken whole n rachel l schade silent kingdom n n'],
#  978: ['backstreet boys quit playing games heart',
#   'backstreet boys quit playing games heart'],
#  979: ['artist yayoi kusama famed involvement 1960s pop art movement celebrate birthday today'],
#  980: ['word eddie keen fisherman fact say shitty little plaice near whales scampy eat irish'],
#  981: ['tsm myth ninja make wan na play fortnite',
#   'stumble across art absolutely amaze make wan na game',
#   'hate ca nt make gifs anymore due stupid watermark wan na make gifs',
#   'make mistake play nier automaton even though 12am wan na sleep soon',
#   'omg drama ripoff brooklyn reading article already make wan na cringe',
#   'nt make film like call name make money make upset mike pence',
#   'decide merch wan na make tire many option let hand move follow ba lololol',
#   'mina make wan na get pet extremely scar dog like dahyun use',
#   'somethin bout make wan na thing nt',
#   'many time wan na make cry',
#   'scan transcript make wan na shoot',
#   'something jay park song make wan na thot',
#   'wan na make java programmer really mad retort nullpointerexception watch face explode',
#   'lol make sense im bore dont wan na anything',
#   'catching s2 ross financial difficulty make wan na send hundred pound',
#   'many time ikon wan na make u cry',
#   'someday wan na make oc charm p v p',
#   'seminar make wan na go skydive without safety gear going',
#   'today s dinner make mom pay much make feel undigested m never gon na go',
#   'today s dinner make mom pay much make feel undigested m never gon na go',
#   'make game competitive make less fun nt',
#   'ahhh see instagram story japan make wan na go back',
#   'buying clothes pet make look cute prevent cold scratch nt make human',
#   'lowkey wan na practice make coffee',
#   'goodnight wan na also dua better make choke',
#   'maaaan wan na try cuban sandwich place nt deliver area s far make trip',
#   'make love next week ca nt please make banner',
#   'get ta make light ridill aughhh',
#   'suit make man snow make cold william shakespeare hamlet',
#   'crowdsourcing think make dent s school market',
#   'nt make everybody ally need make enemy'],
#  982: ['someone love facebook help destress much ridiculous vids meme hahahahhahah'],
#  983: ['whenever reach gold protrait though ll buy account alt ikol',
#   'whenever reach gold portrait though ll buy account alt ikol'],
#  984: ['also hey new run bts ep go'],
#  985: ['hahah damn keep giggling aibou sugishita best'],
#  986: ['duty palm increase close whats happen india pandering farmer lobby election year'],
#  987: ['watch run bts late ep make love w barista taetae'],
#  988: ['give straight wrinkle time giver level adaptation'],
#  989: ['btw passion hoarder tooooooo paralyze haha'],
#  990: ['simei rc girl kwon eun bin',
#   'devoted direct girls simei rc girl also kwon eun bin lucky life getting luckier move army'],
#  991: ['culture ask fact ask heart moment breath'],
#  992: ['spirit mind mind matter s simple n sahndra fon dufe n n',
#   'say feel mind nt matter matter nt mind dr seuss via'],
#  993: ['10 video watch week video mins min mod cover hour lecture help laaaaaaa'],
#  994: ['someone tell host drag race thailand ugly drag queen',
#   'omg contestant drag race thailand cute groom outfit shake',
#   'omg drag queen show penanggal drag'],
#  995: ['do nt need deny hurt lie thing swear know',
#   'submitting assignment minute deadline much handle omg head hurt',
#   'start fill form hand start tire hurt write name',
#   'beware honest hurt feel clean morrigan wicked divine',
#   's upside hurt sometimes happen reason',
#   'arm shoulder hurt carry furniture bunk',
#   'try work post schedule brain hurt ahahahaha',
#   'ankle hurt cant walk properly ankle soul hurt',
#   'cant make mind hurt see either u like liddat',
#   'omg wonder heize s mianhae personality medium fan people hurt',
#   'mind sore think eye sore cry heart sore hurt goodnight',
#   'stomach hurt m sure giveaway ong seal',
#   '20152016 lose colleague grandmother self confidence etc get hurt internally people get direction',
#   'oooh deja hurt mother leave rebellious deja',
#   'think song would hurt habit happen gdi changjo idk thank',
#   'good lord favs afs face favs mvp hurt either way dangit',
#   'lot people fandom thing voluntarily freelance nt hurt kind like person lol',
#   'cant wait future w boyfriend like hop last relationship bc idw get hurt againn',
#   'aint nobody hurt u like hurt one love like',
#   'ache dragonboating make discover muscle never know existed fucking hurt masochist love',
#   'fun today walk around sentosa friend mess around die arcade hahahah core hurt rn',
#   'weird someone say word could hurt u many way',
#   'excited ultra n nsaturday 1pm umf radio stage n n also secret b2bs around mi hed hurt lol',
#   'hate cry m frustrate angry people think m hurt m really try kill',
#   'long decision nt hurt anyone deserve prioritize happiness everyone s opinion',
#   'wound cover band aid whenever band aid tear wound start hurt',
#   'hate hear re hurt m try best heal make happy',
#   'hurt deserve nt even know nt even clue m hurt',
#   'god damn right rib really hurt lol need ice something',
#   'stomach still hurt knn ughh feel like throw try decide still head work',
#   'hahah kid recognize patini unnie yoona s hurt lol'],
#  996: ['really like frente s version bizzare love triangle much'],
#  997: ['jazzer want second hand set headphone eddie grundy keep toilet gift someone s lucky lady'],
#  998: ['im literally star makestar checkout page wonder proceed aksfgalsfjahsljdgh'],
#  999: ['re oomf screenshots others send oomfs congratulation'],
#  ...}
