# %%
import requests
import urllib
from micromort.models.trained_models.svm_mean_embeddings import Classifier, MeanEmbeddingVectorizer

# %% [markdown]
# ### Get the tweets

# %%
#tweets = ["@krystalsunbae ILY BABE and lmao same.. its too tru","RT @bhj9256: 소름이 돋아 백현이랑 경수 둘다 잔망잔마유ㅠㅠㅠㅠㅠㅠ https://t.co/HxCz0Rc9jo","2 accidents at PIE! 😩","RT @brainpicker: Bruce Lee, who would've been 77 today, on self-actualization and the crucial difference between pride and self-este… ","https://t.co/kAeV5X9EM7","RT @Bulletproof_SG: BTS on The Ellen Show insta story \n#방탄소년단 @BTS_twt https://t.co/KRmDbp8Rh3","York Hotel introduces new a la carte comfort food. https://t.co/8VkZNwWv8X","RT @C_Hendrick: “It's impossible to think \"out of the box\" when you're stuck inside a box with a bunch of other people.” https://t.co/xKaHe…","i want to cosplay hypnosis mic ajkfasga","How to invest in The Anthropocene? https://t.co/s7aczvAI13","RT @SeanAstin: I accept. https://t.co/v7j4uXcvnW","RT @billboard: Did you catch BTS on Ellen? #BillboardNews https://t.co/XprSAPpEjq","OMU Singapore – Lava Omurice With Creamy Centre Comes To Singapore, At Suntec City https://t.co/jJzTnwNFpw","i really want to be in korea now sigh","the way b.a.p reaction when dae is undressing jongup 😂 https://t.co/VOJxbCoXTu","RT @Alvinchong123: Morning sunshine!","RT @AdamOfEarth: Anxiety is like a dandelion; it grows quickly, returns unpredictably, people spend millions a year to treat it, and… ","RT @Koreaboo: TWICE is working with the Seoul Metropolitan Police Agency to make sure everyone knows how to report child abuse! 👮… ","But before they turned from what they craved,\n    even while the food was still in their mouths,\n\n@mor1019… https://t.co/tvF7NNwRIu","@vaishnavi My niece &amp; her family stranded in Kuta Bali too. Not sure what alternatives they're taking to come back safely to 🇸🇬.."] 
tweets = [row.strip() for row in open("../tweets","r").readlines() ]

# %% [markdown]
# #### Get the cleaned tweets:

# %%
cleaned_tweets = [row.strip() for row in open("../cleaned_tweets","r").readlines() ]

# %% [markdown]
# ### Clean the tweets

# %%
def preprocess_text(str, level=2):
   r = requests.get("http://172.29.33.45:8000/textpreprocessor/{}?text={}".format(level, urllib.quote_plus(str)))
   return r.json()

# %%
cleaned_tweets = []
for tweet in tweets:
    clean_json = preprocess_text(tweet)
    _str = ""
    for token in clean_json['token_list']:
       if token["core"]["class"] in [10]:
            _str += token["core"]["token"] + " "
    cleaned_tweets.append(_str.strip())

# %%
for index in range(0,100):
    print "Original tweet:\n" + str(tweets[index]) + "\nCleaned :\n" + str(cleaned_tweets[index]) + "\n\n\n"
# Out:
# Original tweet:
# Repost from nabbasingapore using repostregramapp - For the first time , we will be presenting ... https://t.co/bzIQKD6bVM
# Cleaned :
# Repost from nabbasingapore using repostregramapp For the first time we will be presenting
#
#
#
# Original tweet:
# Hi ( @ Pekan Sg . Yan in Yan Besar , Kedah w / @sashimuruhan ) https://t.co/7HphikXXYR
# Cleaned :
# Hi @ Pekan Sg Yan in Yan Besar Kedah w
#
#
#
# Original tweet:
# University Press Subscription - https://t.co/vH0bgM4dpq - https://t.co/DJpYxZbnnJ
# Cleaned :
# University Press Subscription
#
#
#
# Original tweet:
# @goatihilator goin 2 get food w and then back home :'(
# Cleaned :
# goin get food w and then back home
#
#
#
# Original tweet:
# @Matoki_Ting @Mecken_NAO ไม่มิ้วดิ ไม่บล็อคด้วย ไม่งั้นเราจะเห็นถิงบนหน้าไทม์ไลน์ได้ไง
# Cleaned :
#
#
#
#
# Original tweet:
# Hopin you aint stoopid
# Cleaned :
# Hopin you aint stoopid
#
#
#
# Original tweet:
# RT @ScribblingGeek : Another #Zelda masterpiece in upon us . How about a Zelda movie ? https://t.co/0GDuMtS129 https://t.co/73eCK0yn9g
# Cleaned :
# RT Another masterpiece in upon us How about a Zelda movie
#
#
#
# Original tweet:
# So handsome !
# Cleaned :
# So handsome
#
#
#
# Original tweet:
# https://t.co/hpJQ5j8OoD
# Cleaned :
#
#
#
#
# Original tweet:
# OMG ! You have to see this . #BIGOLIVE . https://t.co/trVwykqkqE
# Cleaned :
# OMG You have to see this
#
#
#
# Original tweet:
# Ready for the AMA with @brianbehlendorf #Hyperledger Singapore . Learn more about blockchains and distributed ledger ... https://t.co/O7zuDDQWjw
# Cleaned :
# Ready for the AMA with Singapore Learn more about blockchains and distributed ledger
#
#
#
# Original tweet:
# Published South Korea Retail Sales Slip 2.2 % In January #forex #trading https://t.co/xycYekC1em
# Cleaned :
# Published South Korea Retail Sales Slip In January
#
#
#
# Original tweet:
# RT @loycaloy45 : @ALDUBBibisOFC @maiden16_SG dalawa sila ni Baste oh ! #MaineCelebration #ALDUBMainetedos
# Cleaned :
# RT dalawa sila ni Baste oh
#
#
#
# Original tweet:
# shite essay sighhhhh is the C+ life real
# Cleaned :
# shite essay sighhhhh is the C+ life real
#
#
#
# Original tweet:
# RT @itsjvli4 : lol am i that boring to talk to or what haha ?
# Cleaned :
# RT lol am i that boring to talk to or what haha
#
#
#
# Original tweet:
# RT @rejection : my life is a joke and i'm not laughing anymore
# Cleaned :
# RT my life is a joke and i'm not laughing anymore
#
#
#
# Original tweet:
# RT @hlmshkr87 : I dunno why but when it comes to FnB especially service when things doesnt go how i expect it i will make a scene .
# Cleaned :
# RT I dunno why but when it comes to FnB especially service when things doesnt go how i expect it i will make a scene
#
#
#
# Original tweet:
# https://t.co/n2Ohtv56zL
# Cleaned :
#
#
#
#
# Original tweet:
# @kaisernextdoor keep going !! ? ? ✨
# Cleaned :
# keep going
#
#
#
# Original tweet:
# RT @champagnefeeI : IT'S SO HARD WHEN UR IN A CUDDLY MOOD AND DON'T HAVE ANYONE TO CUDDLE WITH THIS IS AN OUTRAGE
# Cleaned :
# RT IT'S SO HARD WHEN UR IN A CUDDLY MOOD AND DON'T HAVE ANYONE TO CUDDLE WITH THIS IS AN OUTRAGE
#
#
#
# Original tweet:
# RT @disneywords : If you give love , you get love back . In other words , what goes around comes around . - Sebastian ( Little Mermaid II )
# Cleaned :
# RT If you give love you get love back In other words what goes around comes around Sebastian Little Mermaid II
#
#
#
# Original tweet:
# I need backup ! Battle ID : 564BEEC0 Lvl 60 Yggdrasil Omega https://t.co/l0nHlPDK58
# Cleaned :
# I need backup Battle ID 564BEEC0 Lvl Yggdrasil Omega
#
#
#
# Original tweet:
# RT @btsjiminsg : Jin and Jimin on Hello Counselor - Episode airs tomorrow at 11.10 PM KST https://t.co/xfDVBmiGTv https://t.co/oSvMFLxNFw
# Cleaned :
# RT Jin and Jimin on Hello Counselor Episode airs PM KST
#
#
#
# Original tweet:
# third wheeling 2 girls who are best friends is sooooooo much worse than 3rd wheeling a couple this is a fact
# Cleaned :
# third wheeling girls who are best friends is sooooooo much worse than 3rd wheeling a couple this is a fact
#
#
#
# Original tweet:
# #OIL : Potential for long-dated prices to decline below $ 50 long term f'cast on shale ramp up , majors shifting to future growth @GoldmanSachs
# Cleaned :
# Potential for long-dated prices to decline below long term f'cast on shale ramp up majors shifting to future growth
#
#
#
# Original tweet:
# RT @monster_1979 : 170312 동욱님 팬밋 꽁\n출처 꽁갤 https://t.co/7l6bEq2Udq https://t.co/vbyEq8cVBa
# Cleaned :
# RT n
#
#
#
# Original tweet:
# RT @MeninistTweet : learn to take a joke ? https://t.co/5N3rTzE46h https://t.co/AdAxDKl2bJ
# Cleaned :
# RT learn to take a joke
#
#
#
# Original tweet:
# RT @YahooSG : Wait - the Oscars cost HOW MUCH ?! https://t.co/H6JGNsr1MJ
# Cleaned :
# RT Wait the Oscars cost HOW MUCH
#
#
#
# Original tweet:
# when school finally brings you to your breaking point https://t.co/GBkN1RChYe
# Cleaned :
# when school finally brings you to your breaking point
#
#
#
# Original tweet:
# @WilliamBibbiani Worth my money Bibbs ?
# Cleaned :
# Worth my money Bibbs
#
#
#
# Original tweet:
# Landslide at Ethiopia garbage dump kills at least 30 https://t.co/3fUu0C7LbK https://t.co/NomiCBbOSD
# Cleaned :
# Landslide at Ethiopia garbage dump kills at least
#
#
#
# Original tweet:
# @TimesNow Mr . Parrikar will be very happy in Goa , Home is where the heart is . He will be surrounded by beaches , trees , fresh air
# Cleaned :
# Mr Parrikar will be very happy in Goa Home is where the heart is He will be surrounded by beaches trees fresh air
#
#
#
# Original tweet:
# https://t.co/E1rXw1HVAO
# Cleaned :
#
#
#
#
# Original tweet:
# #Love is #blind . If #all #you #see are #flaws , that's not love . #qotd #romance #badromance
# Cleaned :
# is If are that's not love
#
#
#
# Original tweet:
# RT @SamsungMobileUS : Shout out to all those who said " you can't . " This one's for you . With love , from @CaseyNeistat . https://t.co/351MuxS35t
# Cleaned :
# RT Shout out to all those who said you can't This one's for you With love from
#
#
#
# Original tweet:
# RT @dailyzen : " We understand that every person has a place ; happiness comes from learning to work within that place " https://t.co/dVPQUihelL
# Cleaned :
# RT We understand that every person has a place happiness comes from learning to work within that place
#
#
#
# Original tweet:
# #Poland : New rules for confiscation of proceeds of crime - update https://t.co/VjCGnao9Ay https://t.co/ogR2P15VVd
# Cleaned :
# New rules for confiscation of proceeds of crime update
#
#
#
# Original tweet:
# RT @Informatica : Get your free copy of Bloor's assessment on the challenges of managing a data lake . REPORT : https://t.co/g08PgxaUoG #Da ...
# Cleaned :
# RT Get your free copy of Bloor's assessment on the challenges of managing a data lake REPORT
#
#
#
# Original tweet:
# IT'S ABOUT TIME
# Cleaned :
# IT'S ABOUT TIME
#
#
#
# Original tweet:
# https://t.co/ySQLHUEVbF Seasons Board Game https://t.co/MhxOlPOYbu #tweet #tradingcards , #tradingcard , #tradingcardgame , card games , Trad ...
# Cleaned :
# Seasons Board Game card games Trad
#
#
#
# Original tweet:
# we'll be alright , even if we're mile apart
# Cleaned :
# we'll be alright even if we're mile apart
#
#
#
# Original tweet:
# #actress #casting #filmmaking KSH will be meeting with the actress's agent at #HK #Filmart . https://t.co/d5yyTAEDei
# Cleaned :
# KSH will be meeting with the actress's agent at
#
#
#
# Original tweet:
# Ingat ni ok krg dua @vrbkysrtbv @fvnanr https://t.co/UvGyKSmU2B
# Cleaned :
# Ingat ni ok krg dua
#
#
#
# Original tweet:
# RT @TheAcademy : And the Oscar goes to ... https://t.co/x6d3SjLQHh
# Cleaned :
# RT And the Oscar goes to
#
#
#
# Original tweet:
# RT @PP351896728 : #KCAFavViralMusicArtist #TiffanyAlvord 1
# Cleaned :
# RT 1
#
#
#
# Original tweet:
# RT @kyunghyang : 헌재 전원일치 파면 결정입니다 . \n박근혜 시대가 끝났습니다 . https://t.co/ILSzmaLm8M
# Cleaned :
# RT n
#
#
#
# Original tweet:
# RT @btswithhearts : and what is most heartbreaking is that these " fans " are giving the entire chile army fandom a bad name , which they do no ...
# Cleaned :
# RT and what is most heartbreaking is that these fans are giving the entire chile army fandom a bad name which they do no
#
#
#
# Original tweet:
# Blue Exorcist : 6 ( Blue Exorcist ) By ( author ) Kazue KATO Blue Exorcist : 6 ( Blue Exorcist ) https://t.co/d2PepgVs7c
# Cleaned :
# Blue Exorcist Blue Exorcist By author Kazue KATO Blue Exorcist Blue Exorcist
#
#
#
# Original tweet:
# 10 / 3 FedEx B777F N843FD ( formerly OO-TSB ) was photographed returning from an air test earlier this morning as ... https://t.co/F1safPqrmJ
# Cleaned :
# 10 FedEx B777F N843FD formerly OO-TSB was photographed returning from an air test earlier this morning as
#
#
#
# Original tweet:
# Star of ' American Guns ' convicted of fraud , tax evasion https://t.co/9YmFA0MvNH
# Cleaned :
# Star of American Guns convicted of fraud tax evasion
#
#
#
# Original tweet:
# 1Netscope : How Losses of Federal Open Data Could Affect IT and Businesses https://t.co/V0KqtNq3tt #BigData ... https://t.co/Nv1gng7KE5
# Cleaned :
# 1Netscope How Losses of Federal Open Data Could Affect IT and Businesses
#
#
#
# Original tweet:
# @ainhatespeanuts ? have faith
# Cleaned :
# have faith
#
#
#
# Original tweet:
# @frhn yeah baby !
# Cleaned :
# yeah baby
#
#
#
# Original tweet:
# RT @worldbizmagz : France stocks higher at close of trade ; CAC 40 up 0.24 %
# Cleaned :
# RT France stocks higher at close of trade CAC up
#
#
#
# Original tweet:
# @RatnaSyafitrii_ nonsenseee youuu ratnaa ?
# Cleaned :
# nonsenseee youuu ratnaa
#
#
#
# Original tweet:
# RT @schumelli1 : To everyone struggling with judgemental types . ? \n\nوَلَا يَحْزُنْكَ قَوْلُهُمْ\n" Do not let their words sadden you ...
# Cleaned :
# RT To everyone struggling with judgemental types n n n Do not let their words sadden you
#
#
#
# Original tweet:
# RT @iamtrbl_ : okay , live x g2 x dumbfoundead x kim hyoeun is gon be so good
# Cleaned :
# RT okay live x g2 x dumbfoundead x kim hyoeun is gon be so good
#
#
#
# Original tweet:
# not this timing ?
# Cleaned :
# not this timing
#
#
#
# Original tweet:
# Just posted a photo @ Regal Hongkong Hotel Unofficial https://t.co/k1aVoZenoA
# Cleaned :
# Just posted a photo @ Regal Hongkong Hotel Unofficial
#
#
#
# Original tweet:
# Nk tukar motor please
# Cleaned :
# Nk tukar motor please
#
#
#
# Original tweet:
# 去死啦朋友 。 。 害到我这么惨 ！ ！ ！ 击败 。 。
# Cleaned :
#
#
#
#
# Original tweet:
# RT @The42_ie : Katie Taylor eases to third pro victory amid fifth-round stoppage : https://t.co/qRIqNstsfp https://t.co/o2LPBNBCSG
# Cleaned :
# RT Katie Taylor eases to third pro victory amid fifth-round stoppage
#
#
#
# Original tweet:
# It's called one country two policies #prccbiz1 https://t.co/DIvcBn5wPU
# Cleaned :
# It's called one country two policies
#
#
#
# Original tweet:
# I like how xingmis stand in a row waving to him and he waves back . So orderly so nice ? yixing we miss youuuu https://t.co/hs7OeDepRy
# Cleaned :
# I like how xingmis stand in a row waving to him and he waves back So orderly so nice yixing we miss youuuu
#
#
#
# Original tweet:
# Me in the future lol https://t.co/P304T9pedk
# Cleaned :
# Me in the future lol
#
#
#
# Original tweet:
# RT @41Strange : Artwork by John Kenn Mortensen https://t.co/0oYqOSgu5H
# Cleaned :
# RT @41Strange Artwork by John Kenn Mortensen
#
#
#
# Original tweet:
# @ThyRealKeyShawn skipping the next training ?
# Cleaned :
# skipping the next training
#
#
#
# Original tweet:
# RT @jay4manutd : None of the Herrera tackles were foul , Hazard rewarded for being a diver . Thank you @fa , thank you Micheal Oliver #CHEMUN
# Cleaned :
# RT None of the Herrera tackles were foul Hazard rewarded for being a diver Thank you thank you Micheal Oliver
#
#
#
# Original tweet:
# Do not blatantly lie @DrAMSinghvi ! Listen to your own MLAs complain . Fact is your leader @digvijaya_28 just lost th ... https://t.co/1WqxuWnEJI
# Cleaned :
# Do not blatantly lie Listen to your own MLAs complain Fact is your leader just lost th
#
#
#
# Original tweet:
# RT @ajplus : What has Nigeria's president been doing for the past two months in London ? ? https://t.co/G6aiXG0zMb
# Cleaned :
# RT What has Nigeria's president been doing for the past two months in London
#
#
#
# Original tweet:
# RT @Vliveofficial : #소녀시대 #태연 눕방계 레전드 찍으셨다 천재아이돌 프로집순이 그아탱 짬바 어마어마했던 탱구 눕방 100 번 봐도 안 질릴 , 버릴 장면 하나 없던 역대급 시간 순삭 확신합니다 .. b #FINE #TAEYEON ▶ htt ...
# Cleaned :
# RT b htt
#
#
#
# Original tweet:
# https://t.co/b08N6EWGle
# Cleaned :
#
#
#
#
# Original tweet:
# Cyclone kills 38 , displaces 53,000 in Madagascar https://t.co/qtegRJHBwW
# Cleaned :
# Cyclone kills displaces in Madagascar
#
#
#
# Original tweet:
# RT @onlynochu : can you believe its been a year since the hongdae incident where jungkook watch street perfs and took loads of selc ...
# Cleaned :
# RT can you believe its been a year since the hongdae incident where jungkook watch street perfs and took loads of selc
#
#
#
# Original tweet:
# 65 things you should know about sleep https://t.co/Qnu7ufwStg https://t.co/rNjmqUVXxE
# Cleaned :
# 65 things you should know about sleep
#
#
#
# Original tweet:
# Ex-MI6 officer Christopher Steele , who was behind dossier of allegations about @realDonaldTrump , has reappeared . https://t.co/TNATWgouFt
# Cleaned :
# Ex-MI6 officer Christopher Steele who was behind dossier of allegations about has reappeared
#
#
#
# Original tweet:
# RT @EmrgencyKittens : #ThisCouldBeUsButYouPlayin https://t.co/89xiAi0WYk
# Cleaned :
# RT
#
#
#
# Original tweet:
# RT @aisyaah_aziz : mengapa harus cinta ? X https://t.co/k2WIkO0lgN
# Cleaned :
# RT mengapa harus cinta X
#
#
#
# Original tweet:
# @frhn @keeweeeee @singnoname @leannalikescats cos in doing so , you're only shutting down the conversation and implying " older = smarter "
# Cleaned :
# cos in doing so you're only shutting down the conversation and implying older smarter
#
#
#
# Original tweet:
# RT @rotikaya : https://t.co/TRADPnxCyP Selepas Fattah Amin , Nabil Ahmad Pula Keluar Buku https://t.co/Qjgf0lHC2c
# Cleaned :
# RT Selepas Fattah Amin Nabil Ahmad Pula Keluar Buku
#
#
#
# Original tweet:
# 寝ちゃダメ ！ ?
# Cleaned :
#
#
#
#
# Original tweet:
# Sleep ?
# Cleaned :
# Sleep
#
#
#
# Original tweet:
# https://t.co/ySQLHUEVbF Sellswords https://t.co/BOIUinzDr1 #tweet #tradingcards , #tradingcard , #tradingcardgame , card games , Trading card ...
# Cleaned :
# Sellswords card games Trading card
#
#
#
# Original tweet:
# RT @xhrexx : lol i didn't know her priority is you bitch don't act like you the best
# Cleaned :
# RT lol i didn't know her priority is you bitch don't act like you the best
#
#
#
# Original tweet:
# Coporate updates : Further liquidation of portfolio : Dear Readers , It is with great pleasure that over a short span ... https://t.co/f9ABVDqgO4
# Cleaned :
# Coporate updates Further liquidation of portfolio Dear Readers It is with great pleasure that over a short span
#
#
#
# Original tweet:
# What Triggers Word of Mouth Marketing to Catch Fire ? by @nireyal Read : https://t.co/dY9FW0mNQB https://t.co/uV0PPFF1Lp
# Cleaned :
# What Triggers Word of Mouth Marketing to Catch Fire by Read
#
#
#
# Original tweet:
# Flowers blooming towards the sky , Has winter finally passed by ?
# Cleaned :
# Flowers blooming towards the sky Has winter finally passed by
#
#
#
# Original tweet:
# RT @itssixwordstory : " Time with you is never wasted . "
# Cleaned :
# RT Time with you is never wasted
#
#
#
# Original tweet:
# RT @zeeqky : when the thing you love , could also be the one that hurts you https://t.co/ciUP7M6md7
# Cleaned :
# RT when the thing you love could also be the one that hurts you
#
#
#
# Original tweet:
# RT @sphasiaone : Monitor lizard tries to open Yishun resident's door , fails , then goes for a swim https://t.co/ZUI0iyyWac https://t.co/kYN3s ...
# Cleaned :
# RT Monitor lizard tries to open Yishun resident's door fails then goes for a swim
#
#
#
# Original tweet:
# RT @dannysimpson : Just gonna put it out there . No offence but I don't think I would ever see @GNev2 training in a Man City Training shirt h ...
# Cleaned :
# RT Just gonna put it out there No offence but I don't think I would ever see training in a Man City Training shirt h
#
#
#
# Original tweet:
# RT @jinnah_tweets : I used religion to get us a country . Just for the sake of argument you know . But you people have gone full retard .
# Cleaned :
# RT I used religion to get us a country Just for the sake of argument you know But you people have gone full retard
#
#
#
# Original tweet:
# This is animal cruelty . https://t.co/njMfPIwPsf
# Cleaned :
# This is animal cruelty
#
#
#
# Original tweet:
# RT @BeAwesome_Laugh : " Feed ur soul by feeding the souls of others with l ? ve , kindness & compassion , Give ur hands to serve & ur hearts t ...
# Cleaned :
# RT Feed ur soul by feeding the souls of others with l ve kindness & compassion Give ur hands to serve & ur hearts t
#
#
#
# Original tweet:
# OMG ! You have to see this . #BIGOLIVE . https://t.co/xd7DKEzoJs
# Cleaned :
# OMG You have to see this
#
#
#
# Original tweet:
# Happening tomorrow ! Click the link below to register your spot . In collaboration with Footsteps to Inspire and in ... https://t.co/xIRG8PU12x
# Cleaned :
# Happening tomorrow Click the link below to register your spot In collaboration with Footsteps to Inspire and in
#
#
#
# Original tweet:
# The #ScarletHeartRyeo feels ? ? ? ❤ ️ ❤ ️ ? ? https://t.co/n1s9Sjr8zV
# Cleaned :
# The feels
#
#
#
# Original tweet:
# RT @iIovespace : sometimes silence can be beautiful https://t.co/fefCzEHMLl
# Cleaned :
# RT sometimes silence can be beautiful
#
#
#
# Original tweet:
# @shimtacos_ @IndoorMunkie my boss female ah nice lie bruh https://t.co/IugUwRSKKZ
# Cleaned :
# my boss female ah nice lie bruh
#
#
#
# Original tweet:
# #hypnotised sex melissa rivers naked https://t.co/tccQA1HQrC
# Cleaned :
# sex melissa rivers naked

# %% [markdown]
# #### Save the cleaned tweets:

# %%
f = open("../cleaned_tweets", "w")
for tweet in cleaned_tweets:
    f.write("%s\n" % tweet)

# %% [markdown]
# ### load the pre trained model

# %%
classifier = Classifier()

# %% [markdown]
# ### Run the model on cleaned tweets

# %%
for tweet in tweets:
    labels = classifier.predict_single(cleaned_tweets[0], with_label=True)
    #if labels[0] != 'not_applicable':
    print tweet + " :::: " + str(labels) + "\n\n\n"
# Out:
# Repost from nabbasingapore using repostregramapp - For the first time , we will be presenting ... https://t.co/bzIQKD6bVM :::: ['not_applicable']
#
#
#
# Hi ( @ Pekan Sg . Yan in Yan Besar , Kedah w / @sashimuruhan ) https://t.co/7HphikXXYR :::: ['not_applicable']
#
#
#
# University Press Subscription - https://t.co/vH0bgM4dpq - https://t.co/DJpYxZbnnJ :::: ['not_applicable']
#
#
#
# @goatihilator goin 2 get food w and then back home :'( :::: ['not_applicable']
#
#
#
# @Matoki_Ting @Mecken_NAO ไม่มิ้วดิ ไม่บล็อคด้วย ไม่งั้นเราจะเห็นถิงบนหน้าไทม์ไลน์ได้ไง :::: ['not_applicable']
#
#
#
# Hopin you aint stoopid :::: ['not_applicable']
#
#
#
# RT @ScribblingGeek : Another #Zelda masterpiece in upon us . How about a Zelda movie ? https://t.co/0GDuMtS129 https://t.co/73eCK0yn9g :::: ['not_applicable']
#
#
#
# So handsome ! :::: ['not_applicable']
#
#
#
# https://t.co/hpJQ5j8OoD :::: ['not_applicable']
#
#
#
# OMG ! You have to see this . #BIGOLIVE . https://t.co/trVwykqkqE :::: ['not_applicable']
#
#
#
# Ready for the AMA with @brianbehlendorf #Hyperledger Singapore . Learn more about blockchains and distributed ledger ... https://t.co/O7zuDDQWjw :::: ['not_applicable']
#
#
#
# Published South Korea Retail Sales Slip 2.2 % In January #forex #trading https://t.co/xycYekC1em :::: ['not_applicable']
#
#
#
# RT @loycaloy45 : @ALDUBBibisOFC @maiden16_SG dalawa sila ni Baste oh ! #MaineCelebration #ALDUBMainetedos :::: ['not_applicable']
#
#
#
# shite essay sighhhhh is the C+ life real :::: ['not_applicable']
#
#
#
# RT @itsjvli4 : lol am i that boring to talk to or what haha ? :::: ['not_applicable']
#
#
#
# RT @rejection : my life is a joke and i'm not laughing anymore :::: ['not_applicable']
#
#
#
# RT @hlmshkr87 : I dunno why but when it comes to FnB especially service when things doesnt go how i expect it i will make a scene . :::: ['not_applicable']
#
#
#
# https://t.co/n2Ohtv56zL :::: ['not_applicable']
#
#
#
# @kaisernextdoor keep going !! ? ? ✨ :::: ['not_applicable']
#
#
#
# RT @champagnefeeI : IT'S SO HARD WHEN UR IN A CUDDLY MOOD AND DON'T HAVE ANYONE TO CUDDLE WITH THIS IS AN OUTRAGE :::: ['not_applicable']
#
#
#
# RT @disneywords : If you give love , you get love back . In other words , what goes around comes around . - Sebastian ( Little Mermaid II ) :::: ['not_applicable']
#
#
#
# I need backup ! Battle ID : 564BEEC0 Lvl 60 Yggdrasil Omega https://t.co/l0nHlPDK58 :::: ['not_applicable']
#
#
#
# RT @btsjiminsg : Jin and Jimin on Hello Counselor - Episode airs tomorrow at 11.10 PM KST https://t.co/xfDVBmiGTv https://t.co/oSvMFLxNFw :::: ['not_applicable']
#
#
#
# third wheeling 2 girls who are best friends is sooooooo much worse than 3rd wheeling a couple this is a fact :::: ['not_applicable']
#
#
#
# #OIL : Potential for long-dated prices to decline below $ 50 long term f'cast on shale ramp up , majors shifting to future growth @GoldmanSachs :::: ['not_applicable']
#
#
#
# RT @monster_1979 : 170312 동욱님 팬밋 꽁\n출처 꽁갤 https://t.co/7l6bEq2Udq https://t.co/vbyEq8cVBa :::: ['not_applicable']
#
#
#
# RT @MeninistTweet : learn to take a joke ? https://t.co/5N3rTzE46h https://t.co/AdAxDKl2bJ :::: ['not_applicable']
#
#
#
# RT @YahooSG : Wait - the Oscars cost HOW MUCH ?! https://t.co/H6JGNsr1MJ :::: ['not_applicable']
#
#
#
# when school finally brings you to your breaking point https://t.co/GBkN1RChYe :::: ['not_applicable']
#
#
#
# @WilliamBibbiani Worth my money Bibbs ? :::: ['not_applicable']
#
#
#
# Landslide at Ethiopia garbage dump kills at least 30 https://t.co/3fUu0C7LbK https://t.co/NomiCBbOSD :::: ['not_applicable']
#
#
#
# @TimesNow Mr . Parrikar will be very happy in Goa , Home is where the heart is . He will be surrounded by beaches , trees , fresh air :::: ['not_applicable']
#
#
#
# https://t.co/E1rXw1HVAO :::: ['not_applicable']
#
#
#
# #Love is #blind . If #all #you #see are #flaws , that's not love . #qotd #romance #badromance :::: ['not_applicable']
#
#
#
# RT @SamsungMobileUS : Shout out to all those who said " you can't . " This one's for you . With love , from @CaseyNeistat . https://t.co/351MuxS35t :::: ['not_applicable']
#
#
#
# RT @dailyzen : " We understand that every person has a place ; happiness comes from learning to work within that place " https://t.co/dVPQUihelL :::: ['not_applicable']
#
#
#
# #Poland : New rules for confiscation of proceeds of crime - update https://t.co/VjCGnao9Ay https://t.co/ogR2P15VVd :::: ['not_applicable']
#
#
#
# RT @Informatica : Get your free copy of Bloor's assessment on the challenges of managing a data lake . REPORT : https://t.co/g08PgxaUoG #Da ... :::: ['not_applicable']
#
#
#
# IT'S ABOUT TIME :::: ['not_applicable']
#
#
#
# https://t.co/ySQLHUEVbF Seasons Board Game https://t.co/MhxOlPOYbu #tweet #tradingcards , #tradingcard , #tradingcardgame , card games , Trad ... :::: ['not_applicable']
#
#
#
# we'll be alright , even if we're mile apart :::: ['not_applicable']
#
#
#
# #actress #casting #filmmaking KSH will be meeting with the actress's agent at #HK #Filmart . https://t.co/d5yyTAEDei :::: ['not_applicable']
#
#
#
# Ingat ni ok krg dua @vrbkysrtbv @fvnanr https://t.co/UvGyKSmU2B :::: ['not_applicable']
#
#
#
# RT @TheAcademy : And the Oscar goes to ... https://t.co/x6d3SjLQHh :::: ['not_applicable']
#
#
#
# RT @PP351896728 : #KCAFavViralMusicArtist #TiffanyAlvord 1 :::: ['not_applicable']
#
#
#
# RT @kyunghyang : 헌재 전원일치 파면 결정입니다 . \n박근혜 시대가 끝났습니다 . https://t.co/ILSzmaLm8M :::: ['not_applicable']
#
#
#
# RT @btswithhearts : and what is most heartbreaking is that these " fans " are giving the entire chile army fandom a bad name , which they do no ... :::: ['not_applicable']
#
#
#
# Blue Exorcist : 6 ( Blue Exorcist ) By ( author ) Kazue KATO Blue Exorcist : 6 ( Blue Exorcist ) https://t.co/d2PepgVs7c :::: ['not_applicable']
#
#
#
# 10 / 3 FedEx B777F N843FD ( formerly OO-TSB ) was photographed returning from an air test earlier this morning as ... https://t.co/F1safPqrmJ :::: ['not_applicable']
#
#
#
# Star of ' American Guns ' convicted of fraud , tax evasion https://t.co/9YmFA0MvNH :::: ['not_applicable']
#
#
#
# 1Netscope : How Losses of Federal Open Data Could Affect IT and Businesses https://t.co/V0KqtNq3tt #BigData ... https://t.co/Nv1gng7KE5 :::: ['not_applicable']
#
#
#
# @ainhatespeanuts ? have faith :::: ['not_applicable']
#
#
#
# @frhn yeah baby ! :::: ['not_applicable']
#
#
#
# RT @worldbizmagz : France stocks higher at close of trade ; CAC 40 up 0.24 % :::: ['not_applicable']
#
#
#
# @RatnaSyafitrii_ nonsenseee youuu ratnaa ? :::: ['not_applicable']
#
#
#
# RT @schumelli1 : To everyone struggling with judgemental types . ? \n\nوَلَا يَحْزُنْكَ قَوْلُهُمْ\n" Do not let their words sadden you ... :::: ['not_applicable']
#
#
#
# RT @iamtrbl_ : okay , live x g2 x dumbfoundead x kim hyoeun is gon be so good :::: ['not_applicable']
#
#
#
# not this timing ? :::: ['not_applicable']
#
#
#
# Just posted a photo @ Regal Hongkong Hotel Unofficial https://t.co/k1aVoZenoA :::: ['not_applicable']
#
#
#
# Nk tukar motor please :::: ['not_applicable']
#
#
#
# 去死啦朋友 。 。 害到我这么惨 ！ ！ ！ 击败 。 。 :::: ['not_applicable']
#
#
#
# RT @The42_ie : Katie Taylor eases to third pro victory amid fifth-round stoppage : https://t.co/qRIqNstsfp https://t.co/o2LPBNBCSG :::: ['not_applicable']
#
#
#
# It's called one country two policies #prccbiz1 https://t.co/DIvcBn5wPU :::: ['not_applicable']
#
#
#
# I like how xingmis stand in a row waving to him and he waves back . So orderly so nice ? yixing we miss youuuu https://t.co/hs7OeDepRy :::: ['not_applicable']
#
#
#
# Me in the future lol https://t.co/P304T9pedk :::: ['not_applicable']
#
#
#
# RT @41Strange : Artwork by John Kenn Mortensen https://t.co/0oYqOSgu5H :::: ['not_applicable']
#
#
#
# @ThyRealKeyShawn skipping the next training ? :::: ['not_applicable']
#
#
#
# RT @jay4manutd : None of the Herrera tackles were foul , Hazard rewarded for being a diver . Thank you @fa , thank you Micheal Oliver #CHEMUN :::: ['not_applicable']
#
#
#
# Do not blatantly lie @DrAMSinghvi ! Listen to your own MLAs complain . Fact is your leader @digvijaya_28 just lost th ... https://t.co/1WqxuWnEJI :::: ['not_applicable']
#
#
#
# RT @ajplus : What has Nigeria's president been doing for the past two months in London ? ? https://t.co/G6aiXG0zMb :::: ['not_applicable']
#
#
#
# RT @Vliveofficial : #소녀시대 #태연 눕방계 레전드 찍으셨다 천재아이돌 프로집순이 그아탱 짬바 어마어마했던 탱구 눕방 100 번 봐도 안 질릴 , 버릴 장면 하나 없던 역대급 시간 순삭 확신합니다 .. b #FINE #TAEYEON ▶ htt ... :::: ['not_applicable']
#
#
#
# https://t.co/b08N6EWGle :::: ['not_applicable']
#
#
#
# Cyclone kills 38 , displaces 53,000 in Madagascar https://t.co/qtegRJHBwW :::: ['not_applicable']
#
#
#
# RT @onlynochu : can you believe its been a year since the hongdae incident where jungkook watch street perfs and took loads of selc ... :::: ['not_applicable']
#
#
#
# 65 things you should know about sleep https://t.co/Qnu7ufwStg https://t.co/rNjmqUVXxE :::: ['not_applicable']
#
#
#
# Ex-MI6 officer Christopher Steele , who was behind dossier of allegations about @realDonaldTrump , has reappeared . https://t.co/TNATWgouFt :::: ['not_applicable']
#
#
#
# RT @EmrgencyKittens : #ThisCouldBeUsButYouPlayin https://t.co/89xiAi0WYk :::: ['not_applicable']
#
#
#
# RT @aisyaah_aziz : mengapa harus cinta ? X https://t.co/k2WIkO0lgN :::: ['not_applicable']
#
#
#
# @frhn @keeweeeee @singnoname @leannalikescats cos in doing so , you're only shutting down the conversation and implying " older = smarter " :::: ['not_applicable']
#
#
#
# RT @rotikaya : https://t.co/TRADPnxCyP Selepas Fattah Amin , Nabil Ahmad Pula Keluar Buku https://t.co/Qjgf0lHC2c :::: ['not_applicable']
#
#
#
# 寝ちゃダメ ！ ? :::: ['not_applicable']
#
#
#
# Sleep ? :::: ['not_applicable']
#
#
#
# https://t.co/ySQLHUEVbF Sellswords https://t.co/BOIUinzDr1 #tweet #tradingcards , #tradingcard , #tradingcardgame , card games , Trading card ... :::: ['not_applicable']
#
#
#
# RT @xhrexx : lol i didn't know her priority is you bitch don't act like you the best :::: ['not_applicable']
#
#
#
# Coporate updates : Further liquidation of portfolio : Dear Readers , It is with great pleasure that over a short span ... https://t.co/f9ABVDqgO4 :::: ['not_applicable']
#
#
#
# What Triggers Word of Mouth Marketing to Catch Fire ? by @nireyal Read : https://t.co/dY9FW0mNQB https://t.co/uV0PPFF1Lp :::: ['not_applicable']
#
#
#
# Flowers blooming towards the sky , Has winter finally passed by ? :::: ['not_applicable']
#
#
#
# RT @itssixwordstory : " Time with you is never wasted . " :::: ['not_applicable']
#
#
#
# RT @zeeqky : when the thing you love , could also be the one that hurts you https://t.co/ciUP7M6md7 :::: ['not_applicable']
#
#
#
# RT @sphasiaone : Monitor lizard tries to open Yishun resident's door , fails , then goes for a swim https://t.co/ZUI0iyyWac https://t.co/kYN3s ... :::: ['not_applicable']
#
#
#
# RT @dannysimpson : Just gonna put it out there . No offence but I don't think I would ever see @GNev2 training in a Man City Training shirt h ... :::: ['not_applicable']
#
#
#
# RT @jinnah_tweets : I used religion to get us a country . Just for the sake of argument you know . But you people have gone full retard . :::: ['not_applicable']
#
#
#
# This is animal cruelty . https://t.co/njMfPIwPsf :::: ['not_applicable']
#
#
#
# RT @BeAwesome_Laugh : " Feed ur soul by feeding the souls of others with l ? ve , kindness & compassion , Give ur hands to serve & ur hearts t ... :::: ['not_applicable']
#
#
#
# OMG ! You have to see this . #BIGOLIVE . https://t.co/xd7DKEzoJs :::: ['not_applicable']
#
#
#
# Happening tomorrow ! Click the link below to register your spot . In collaboration with Footsteps to Inspire and in ... https://t.co/xIRG8PU12x :::: ['not_applicable']
#
#
#
# The #ScarletHeartRyeo feels ? ? ? ❤ ️ ❤ ️ ? ? https://t.co/n1s9Sjr8zV :::: ['not_applicable']
#
#
#
# RT @iIovespace : sometimes silence can be beautiful https://t.co/fefCzEHMLl :::: ['not_applicable']
#
#
#
# @shimtacos_ @IndoorMunkie my boss female ah nice lie bruh https://t.co/IugUwRSKKZ :::: ['not_applicable']
#
#
#
# #hypnotised sex melissa rivers naked https://t.co/tccQA1HQrC :::: ['not_applicable']
#
#
#
# RT @realwbonner : Por favor , gente ! Sile ̂ ncio ! Olha a hora ! :::: ['not_applicable']
#
#
#
# RT @seanspicer : the good ole days -- what I would give to hide in a bunny costume again https://t.co/QOlPBsMwMA :::: ['not_applicable']
#
#
#
# RT @parkjamjam_kr : 170312 WINGS TOUR in santiago #JIMIN #지민 not today https://t.co/Ch2eA8AIJ8 :::: ['not_applicable']
#
#
#
# RT @anakuma_371 : しかしひでえな ❗ ️ ? https://t.co/dXo9dBSVQP :::: ['not_applicable']
#
#
#
# @quraesya its not that feeling one but thanks for noticing fam :::: ['not_applicable']
# да потому что очень хороший пример для events / tourism :D :::: ['not_applicable']
#
#
#
# Millennials snapping up Snap stock out of love https://t.co/CCfOG4j3x4 https://t.co/spj0UhHDdo :::: ['not_applicable']
#
#
#
# Warehouse / Logistics Assistant x 10 - People Profilers Pte Ltd https://t.co/DmAy5ykrX9 :::: ['not_applicable']
#
#
#
# RT @MCMikeSkywalker : @ChrisCamozzi lets just say #AndNew :::: ['not_applicable']
#
#
#
# wt kind of slipn habit is tt ? urs ? :::: ['not_applicable']
#
#
#
# RT @1followernodad : this statue OF A LITTLE GIRL was there for 2 days before becoming a sexual object as a joke for men . How long will ... :::: ['not_applicable']
#
#
#
# Over at @Grab our women leaders are doing great things and making a difference to the lives of people in South East ... https://t.co/4BRExU1WV6 :::: ['not_applicable']
#
#
#
# RT @Puribro : LMFAOOOOOOOOOOOOOOOOOOOOOOO https://t.co/BgzVEcf2k7 :::: ['not_applicable']
#
#
#
# @tou_rin3 ( ≧ ∇ ≦ ) b こちらこそよろしくお願いします ！ :::: ['not_applicable']
#
#
#
# RT @strumnrun : 170310 뮤직뱅크 재출근 \n\n#성진 #Sungjin #데이식스 #DAY6 #어떻게말해 #HowCanISay \n\n저기 ... 선배님 ... >///< https://t.co/pROnP0VK8D :::: ['not_applicable']
#
#
#
# experience design has a ' north star formula ' . #ux #uxdesign @Foolproof_UX #designthinking #foolproofSG ... https://t.co/z5KjPl9blJ :::: ['not_applicable']
#
#
#
# RT @BelievePHQ : 50 reasons why parents should encourage their children to play sport https://t.co/Nft3ipHsMH :::: ['not_applicable']
#
#
#
# @jerlynhoooo @PrettyShuWei hahaha then who made your day ?? ;) :::: ['not_applicable']
#
#
#
# RT @sufyashraf : listen to the " wajah " part https://t.co/yJpv6fQYp4 :::: ['not_applicable']
#
#
#
# Happy Founder's Day ? https://t.co/LeP1Y9PIvd :::: ['not_applicable']
#
#
#
# Done Liked & Shared . ❤ #DinTaiFungSG https://t.co/SC1gXNXrGm :::: ['not_applicable']
#
#
#
# https://t.co/ytLU1lYhJj :::: ['not_applicable']
#
#
#
# @IlyaMsrh__ awakkkk balas lerrr .. nak mintak tolong ni ? :::: ['not_applicable']
#
#
#
# [ PREVIEW ] 170311 \n#방탄소년단 #BTSinChile #TheWingsTourInSantiago DAY1 - SUGA [ c : flame _ suga ] https://t.co/GP3QDEiWzc :::: ['not_applicable']
#
#
#
# When you remember it is your friend birthday tomorrow & you have not got her anything lol hahaha . :::: ['not_applicable']
#
#
#
# @_nazimahs ok betul jugak ah . But dia at least suka main depan :::: ['not_applicable']
#
#
#
# RT @Manstagram_ : When you're on your way to Krypton but end up in Kompton https://t.co/DdQFOC6e25 :::: ['not_applicable']
#
#
#
# totally our codes / layout from last year :::: ['not_applicable']
#
#
#
# Everyday : One day i will organise update and re-do my thread .. But that say is not today :::: ['not_applicable']
#
#
#
# RT @JE0NBUNNY : MC : How many times did u watched ur Spring Day MV ? Members : " once " " 3 times " Meanwhile there's Jungkook : HE GOT jIN'S CONFI ... :::: ['not_applicable']
#
#
#
# Beauty and the Beast fans in Sydney welcome ' queer ' twist https://t.co/nvSgGT4NNf #abcnews :::: ['not_applicable']
#
#
#
# Lenten Daily Good Deed No . 1 . #MadeToLove #ReturnToGod #BeKind #LoveNotHate ( at La Salle University- Ozamiz City ) https://t.co/T7CntgQhSN :::: ['not_applicable']
#
#
#
# RT @hopeplus0218 : 170311 꼬까옷입은 버전의 뱁새 \n호석이 오늘도 최고였지 ? ? ? ? #TheWingsTourInChile #홉이 #제이홉 #정호석 @BTS_twt https://t.co/KCkGhGseCy :::: ['not_applicable']
#
#
#
# RT @badethsexy : Hanap pa ng iba nandito naman ako ? ? :::: ['not_applicable']
#
#
#
# @ASTRONAUTICAL__ which library you guys were at omg :::: ['not_applicable']
#
#
#
# RT @amrul_haziq : So me and my friend tried to cover 16 by @MorningMartians last night . https://t.co/Tcet6wb5wv :::: ['not_applicable']
#
#
#
# You are a pro at getting to the bottom of a mystery , willing t ... More for Virgo https://t.co/EQktiu3uZR :::: ['not_applicable']
#
#
#
# RT @prncssant : This boys and girls . Yall gotta understand this . https://t.co/yx3xnfohnx :::: ['not_applicable']
#
#
#
# RT @QiBambiMin : Oh wow . Really ? Like as if i didn't experience it before it stated https://t.co/gIquiivwzw :::: ['not_applicable']
#
#
#
# RT @Harfifi : Asalkan boleh sabar tu sabar insyallah Allah permudahkan . Amin . :::: ['not_applicable']
#
#
#
# @isvariya yes because u HR :::: ['not_applicable']
#
#
#
# @SIRMANTHAALEONG so am I cute now ? ? :::: ['not_applicable']
#
#
#
# RT @mischino24 : hahaha pooor sohee gosh remember this funny gifs from wfs ? ? ? https://t.co/xRDVInHA7c :::: ['not_applicable']
#
#
#
# RT @iconlawrence : name a more iconic dubsmash , i'll wait . https://t.co/VcfBgwx3ER :::: ['not_applicable']
#
#
#
# RT @mynephilim : jungkook really has double helix now ... it looks ... I'm ... bih I choked he looks so damn good with them https://t.co/aiAMhbAyb1 :::: ['not_applicable']
#
#
#
# #dailymarker30daychallenge Its hard keeping up with the daily challenge with the busy schedule .... https://t.co/g2nfi2RjEX :::: ['not_applicable']
#
#
#
# RT @yabu_hika_u : けとりんがもってるカレンダーに注目しすぎて薮くん見てなかったんだけど 、 まって薮くん何してんの ？ ？ 可愛すぎなんだけど ！ ！ ！ ！ https://t.co/HLe44reHte :::: ['not_applicable']
#
#
#
# https://t.co/rBrVr1zKCC :::: ['not_applicable']
#
#
#
# RT @rvz3li : so my sister and nephews are scared of cats . (': https://t.co/memA6X1juy :::: ['not_applicable']
#
#
#
# RT @_nadhy_ : Tkde class lah hais ? ? ? ? ? https://t.co/ZxMrvRr8v6 :::: ['not_applicable']
#
#
#
# Our review of #KongSkullIsland https://t.co/YLh11RfjY6 https://t.co/oY6YwIWbPV :::: ['not_applicable']
#
#
#
# RT @Uber_SING : Save $ 35 on weekday travel ! Apply 7RIDES & take 1 ride to get $ 5 off 7 rides from now till Fri , 11 : 59PM . Limited re ... :::: ['not_applicable']
#
#
#
# RT @artpopfuckedme : When will your faves ? https://t.co/hrBq8izWbH :::: ['not_applicable']
#
#
#
# RT @justrantx : Angus beef slice ? ? YUM YUM ! Come to CHICKATA BBQ | 46 Telok Blangah Drive # 01-71 . MUSLIM OWNED / HALAL ? https://t.co/D0kni8d ... :::: ['not_applicable']
#
#
#
# RT @RunningManGuest : Running Man Ep . 342 is cancelled , because of the breaking news about ex-president Park . Ep . 342 will be on air on March ... :::: ['not_applicable']
#
#
#
# The latest The Technology Channel Daily ! https://t.co/Wky9HdOkhh #mwc17 #oscars :::: ['not_applicable']
#
#
#
# Buti na lang wala sila sa ASAP . charot ... #QuenAt25in19days https://t.co/XxKRtiXrdB :::: ['not_applicable']
#
#
#
# RT @Farivar_S : this Hijabi girl got verbaly abused by a group of men & was upset , so her husband wasnt going to take any of it , and ... :::: ['not_applicable']
#
#
#
# RT @SooFunnyPost : I'M CRYING ? ? https://t.co/oIBgiW9rqO :::: ['not_applicable']
#
#
#
# Lazing around the sofa and waiting for the next day is the only thing I can do now :::: ['not_applicable']
#
#
#
# Praying so hard that I'll get into an accident tonight . :::: ['not_applicable']
#
#
#
# Published German ZEW Economic Confidence Rises Less Than Forecast #forex #trading https://t.co/occSy72WS7 :::: ['not_applicable']
#
#
#
# @7upz you're overdressed . But yay to end of reservist ! :::: ['not_applicable']
#
#
#
# @lelejang they are demons :::: ['not_applicable']
#
#
#
# Adam Savage Behind the Scenes of Ghost in the Shell ! https://t.co/W3ouyRROkB ( OMG ! The precision design of the props are amazing ! ) :::: ['not_applicable']
#
#
#
# RT @IvankaTrump : Epic first Monster Truck show with the kids ! #MonsterJam https://t.co/a0beqvg1tn :::: ['not_applicable']
#
#
#
# Last mjnute shopping -- Best place to look for my Matcha candy sweets . Nomnomnom !! My friend ... https://t.co/HkUxHYr4Uj :::: ['not_applicable']
#
#
#
# RT @ajizla : Member sebelah tahan ketawa je ? https://t.co/lkiRN4CqZo :::: ['not_applicable']
#
#
#
# RT @sanacottoncandy : 170304 여의도 팬싸인회 #트와이스 #사나 #TWICE #SANA @JYPETWICE \n샤샤 ..... 셀카 풀어주라 ... >.< https://t.co/m4asp7nlY3 :::: ['not_applicable']
#
#
#
# RT @LFCTransferRoom : ? VIDEO | Xabi Alonso & former AC Milan manager Ancelotti joke about 2005 Champions League Final . [ @iMiaSanMia ] #LFC h ... :::: ['not_applicable']
#
#
#
# RT @changjaeftw : lmaooo is this changsub's model ? https://t.co/F5qYVwmOSf :::: ['not_applicable']
#
#
#
# RT @SixSecondCov : Just going to leave this here https://t.co/HruFkjrTnf :::: ['not_applicable']
#
#
#
# RT @bjorbork : holy shit guys it's happening already https://t.co/MXYIqZU9wa :::: ['not_applicable']
#
#
#
# Please do this to me if I ever die https://t.co/6gjBczl5Id :::: ['not_applicable']
#
#
#
# RT @bernamadotcom Najib regards the opposition in Malaysia as Ali Baba https://t.co/OmA9eyLghA :::: ['not_applicable']
#
#
#
# Click to agree with what ? No one reads terms of service , studies confirm . https://t.co/alwIMuBL0a :::: ['not_applicable']
#
#
#
# Ikal : " Korang tak active ah . "\n Fad : " Pagi2 buta nak active ape ? "\n Ikal : " Eh , pagi tak boleh buta pagi takde mata . " ? :::: ['not_applicable']
#
#
#
# #longhair women girl nude walking progress https://t.co/2wlmCuQbby :::: ['not_applicable']
#
#
#
# RT @cupcake_aisyah : what the fuck shut the fuck up :::: ['not_applicable']
#
#
#
# RT @_yychee : hahahah i died https://t.co/sQOQw2gpaK :::: ['not_applicable']
#
#
#
# RT @tease : Ok this is the best romantic gesture I've seen by far ? ? https://t.co/08m38Azl8Z :::: ['not_applicable']
#
#
#
# i hate !!!! public transport !!!! :::: ['not_applicable']
#
#
#
# ? ? ? ? https://t.co/sLuIvdTqJL :::: ['not_applicable']
#
#
#
# Karthi is a fine actor in his own right ... He no longer stands in his brother's shadow BUT This role can only be owned by his brother :::: ['not_applicable']
#
#
#
# #Barc ̧ a ̀ https://t.co/hFXdgcsvdO :::: ['not_applicable']
#
#
#
# RT @selfamused : There is a thing about drama https://t.co/x7CjMzkZYz :::: ['not_applicable']
#
#
#
# RT @freezekookie : Oh my god that is jeongguk , look at him brushing his hair back wtf o << ? ? https://t.co/sYvkmfT6RR :::: ['not_applicable']
#
#
#
# Been feeling weird earlier last week , work and too many things had left me pre occupied . I knew ... https://t.co/EZLnR4Abua :::: ['not_applicable']
#
#
#
# RT @helpmeskeletor : POC twitter is the friend you want at your back when Matt Damons are mobbing your Great Wall . https://t.co/wkpsdeKq7c :::: ['not_applicable']
#
#
#
# RT @nazminhakimi : Amik Kau ! Mati x leh tanam https://t.co/4uGiRfQHTU :::: ['not_applicable']
#
#
#
# Fuck . My right ear is fcked . Hit my head too hard . Cant hear properly now ... weewoo . #nsthings :::: ['not_applicable']
#
#
#
# RT @MonicaLaire : My little brother singing for his frist high school talent show is so precious i cry https://t.co/NfhBcbTRiR :::: ['not_applicable']
#
#
#
# RT @kmlrzmn : ? ? https://t.co/iZsidC0zDa :::: ['not_applicable']
#
#
#
# RT @forest_fr1ends : so beryl , what part of 'sit the f**k down and i'll bring it over' , are you struggling with today ...? https://t.co/n9YNh ... :::: ['not_applicable']
#
#
#
# RT @akshaykumar : Wishing you all a colourful year ahead ! Have fun , keeping everyone's fun in mind . #HappyHoli !! Be safe . https://t.co/yMai ... :::: ['not_applicable']
#
#
#
# RT @YassiNaenae : two Happy3rd YASNERsary :::: ['not_applicable']
#
#
#
# https://t.co/HYsVZ2xdpe :::: ['not_applicable']
#
#
#
# Well , not heart attack for sure I THINK LOL Ironic- Idk lmao kms :::: ['not_applicable']
#
#
#
# RT @macharge : メイド衣装を事務所に持ち帰って来た鷺沢文香さん１９歳 。 https://t.co/zvOR5TKCKc :::: ['not_applicable']
#
#
#
# RT @Ylette26 : We've become such an overly sensitive society . Stop taking things so personal ! I promise , you'll be a lot happier when you br ... :::: ['not_applicable']
#
#
#
# RT @GordonRamsay : Looks like a camel has lost one of his balls .... are you sure that's a scotch egg ? https://t.co/K3W1UvmwwE :::: ['not_applicable']
#
#
#
# RT @allkpop : HIGHLIGHT reveal group and individual concept photos for 1st mini album , ' Can You Feel It ? ' https://t.co/EcsB5rMd2p https : // t .... :::: ['not_applicable']
#
#
#
# RT @itscharmayne : @jtothekpop hahahaha wag ka nga EightMonthsOfLove MCLISSE :::: ['not_applicable']
#
#
#
# RT @SingtoFanclub : มอนิ่งค่ะ .. ? วันนี้ก็เต็มที่อีกวัน . #SingtoPrachaya #บ้านสิงโตคําราม https://t.co/Hzb35vGBJK :::: ['not_applicable']
#
#
#
# SO PRETTY ~~ I WANTT ? https://t.co/FOzIsYhcJ2 :::: ['not_applicable']
#
#
#
# @yyourclassmate Same . Haha . Ask yuhao create squad , then we join in . ? :::: ['not_applicable']
#
#
#
# @joshm118 @marktivates @ktaewonh @97sTia @Xiaxue @Licheol88 When she block you but her cover photo says dont leave . ? ? ? ? :::: ['not_applicable']
#
#
#
# https://t.co/rum5R5o05r :::: ['not_applicable']
#
#
#
# RT @SpursOfficial : 94 - Goal to Chelsea . Malouda . 1-5 . :::: ['not_applicable']
#
#
#
# RT @zeeqky : when the thing you love , could also be the one that hurts you https://t.co/ciUP7M6md7 :::: ['not_applicable']
# RT @purin0315kj : ★ 亀梨和也 「 ボク 、 運命の人です 。 」 https://t.co/OPuHJcqHT1 :::: ['not_applicable']
#
#
#
# RT @iIovepastels : Oceanic love https://t.co/9zEX2k06r9 :::: ['not_applicable']
#
#
#
# RT @Tooterson : boop https://t.co/zARvYvQAmK :::: ['not_applicable']
#
#
#
# RT @Its21Saavage : Never apologize for being you :::: ['not_applicable']
#
#
#
# RT @xfieq : Setahu aku perempuan paling menyampah bila laki bergurau then sebut " aku rogol kau kang " Am i right ? Tapi tak tahulah kalau a ... :::: ['not_applicable']
#
#
#
# RT @notbangsieyalah : @VanessaHudgens Pak Ang Vanessa Hudgens ng pilipinas c Vivoree @notvivoree #StandStrongMarVoree https://t.co/Pd8Y6gT ... :::: ['not_applicable']
#
#
#
# RT @hellobangsie : Still cant get over our Japan trip ! Like my hair buns ? Thanks to @CreamSilkPH , my hair is strong and healthy ! https://t.c ... :::: ['not_applicable']
#
#
#
# RT @5HDailyStats : #FifthHarmony #YouKnowYouLoveThem @radiodisney https://t.co/T3dDFf6agG :::: ['not_applicable']
#
#
#
# RT @kennagq : Giggs can give every player in arsenal starting a league medal and 2 will remain for Wenger and Bould . Philanthropist http ... :::: ['not_applicable']
#
#
#
# RT @TheDeeKosh : I can't stand people who say " let the past be the past " . Yes . It's one thing to forgive - it's another to forget :::: ['not_applicable']
#
#
#
# RT @Wetty_LizQuen : MEAW Super Mega Blockbuster Day 23 Na ! #THANKYOUMyExAndWhysTeam thank You Lord ! https://t.co/ZQ7MHnt0Rv :::: ['not_applicable']
#
#
#
# RT @kookminzip : https://t.co/SfVcSwRXJr https://t.co/v9yyIGzfEl :::: ['not_applicable']
#
#
#
# RT @inchyrah : ya i look like im having fun all but fcking deep inside i miss u so so much ??? :::: ['not_applicable']
#
#
#
# ❤ ️ :::: ['not_applicable']
#
#
#
# @tarafrejas Setting up the shot doesn't take too long ! Maybe 10 -20mins ? Haha or even less , I don't really time myself . :::: ['not_applicable']
#
#
#
# RT @dopeshow8 : #슈가생일ᄎᄏ #민윤기_생일_캡짜앙 #HAPPYSUGADAY ✨ ✨ ✨ ✨ ✨ ✨ ? ? ? ? ? ⚡ ️ ⚡ ️ ⚡ ️ ? 캡캡짱 !!!!!!!!!!!!!!!!!!!!!!! ? ⚡ ️ ⚡ ️ ⚡ ️ ⚡ ️ ? ‍ ❤ ️‍ ? ? ? ? ? ? ? ✨ ✨ ✨ ✨ https://t.co/LtiFYw ... :::: ['not_applicable']
#
#
#
# RT @piersmorgan : Just GO , for God's sake . #WengerOUT :::: ['not_applicable']
#
#
#
# RT @asonofapeach : Earn your own $ 20 . 2017 . Equal rights for all . Bye . https://t.co/ziVfmveCOo :::: ['not_applicable']
#
#
#
# Sad ? Maybe i dont know haha :::: ['not_applicable']
#
#
#
# Being an Indian Muslim is the complicated thing ever . We do things in Indian way instead of Islamic . And that's where all the problem lies . :::: ['not_applicable']
#
#
#
# RT @wartsilacorp : Change is inevitable . I have learnt to master it with constant vigilance . #BeBoldForChange #IWD2017 #Wa ̈ rtsila ̈ https://t.c ... :::: ['not_applicable']
#
#
#
# @michi_cocopop Supposedly . But deep down inside , we all know we're lying to ourselves :::: ['not_applicable']
#
#
#
# @sheikh_izzuddin saje je dia ni :::: ['not_applicable']
#
#
#
# RT @03 _ knt _ 13 : ふまけんんんんんんんん\n\n見つめあってるるるるるる https://t.co/YYT50bxnpu :::: ['not_applicable']
#
#
#
# https://t.co/5NtBbIIn3s :::: ['not_applicable']
#
#
#
# Day1 ! #MWC17 . #RugGear #RG910 , the high-end #tablet with advanced #outdoor features . Visit Stand 6H46 , Hall 6 for m ... https://t.co/5X2rxoSFTU :::: ['not_applicable']
#
#
#
# @teeyarawr this is like what I said ystd HAHA :::: ['not_applicable']
#
#
#
# Closed Buy 1.4 Lots EURUSD 1.05158 for +10.1 pips , total for today +10.1 pips #PAMM #ProfitSystem #Money #FundManagement #FastGrowth :::: ['not_applicable']
#
#
#
# @YVKXZ your legs ? :::: ['not_applicable']
#
#
#
# RT @ShaunKing : Facing 20 + years in prison for the murder of #QuasonTurner + fleeing , the judge instead opted to give her PROBATION https : / ... :::: ['not_applicable']
#
#
#
# Playing yesterday on the #cmexkey #lenovo #korgmonopoly #yogahome500 #electropop ... https://t.co/T6XsleSJJ8 :::: ['not_applicable']
#
#
#
# RT @Ari_Naeunie : Damn look at them ? https://t.co/IBNwLP3Swr :::: ['not_applicable']
#
#
#
# RT @Footy_Jokes : Awkward . https://t.co/78YGTHLhgP :::: ['not_applicable']
#
#
#
# RT @FNC_ENT : [ Happy Birthday ] #태양 #TaeYang #HappyTAEYANGDay #TAEYANGDay 2 월 28 일 #SF9 태양의 생일을 축하해주세요 ♥ @SF9official https://t.co/QpqLYZSF1u :::: ['not_applicable']
#
#
#
# The one thing that takes listening to rain in your car to the next level is a windshield that stretches up to the back of your head . :::: ['not_applicable']
#
#
#
# RT @Nelse_u : 20170312 이동욱 팬미팅 개존잼 ㅋㅋㅋㅋㅋㅋ\n존잘러 최고된다 ㅋㅋㅋㅋㅋ\n이동욱 공유 깨비 저승이 https://t.co/IbzUGFmdyc :::: ['not_applicable']
#
#
#
# RT @StreetArt360 : Anonymous by Otto Schade https://t.co/J2FR2MLc3o\n #streetart #art #graffiti #anonymous https://t.co/mMZpcpPfyx :::: ['not_applicable']
#
#
#
# RT @nutjereon : Q : Jun says Vernon is pretty , does Vernon dislike it or have you ever told him to stop ? Vernon : no ㅋㅋㅋㅋ i really love it ... :::: ['not_applicable']
#
#
#
# @Zahra_LuvsYou hmm ok dai Will do . Thanks :::: ['not_applicable']
#
#
#
# RT @tyleroakley : OH . MY . GOD . #Oscars :::: ['not_applicable']
#
#
#
# ah this https://t.co/svaoynOamT :::: ['not_applicable']
#
#
#
# @BTS_twt TATEYETESIS :::: ['not_applicable']
#
#
#
# RT @AZU_MOE : こんな狂気に満ちたジグソーパズル見たことない https://t.co/ImkmePGGFd :::: ['not_applicable']
#
#
#
# #singaporebizupdate Tens of Thousands Join Exodus From Mosul as Iraq Renews Offensive https://t.co/wd2PibhYoL :::: ['not_applicable']
#
#
#
# I can't watch run bts I have bio to study for https://t.co/Cmb2bdd5WD :::: ['not_applicable']
#
#
#
# RT @chewjian23 : Fuckboys' motto be like " cheat on your side hoes but don't cheat on your workouts " :::: ['not_applicable']
#
#
#
# RT @shinoseppun : TAKA YOU'RE LATE :::: ['not_applicable']
#
#
#
# Rip last haircut before gp yesterday . Because when we graduate , we need to have the signature recruit look . :::: ['not_applicable']
#
#
#
# RT @DAR_M00N : 리더님이 요섭이가 처음 엠씨맡은 방송이기도 하고 기꺼운 마음으로 응원하러 왔다 뭐 이런식으루 얘기하구 , MC 가 콜라보 제의 받았을 때 어땠냐고 물어봐서 기광이가 이문세 선생님이라고 불렀다가 이문세님이 그렇게 부르지 말라고 ㅋ ... :::: ['not_applicable']
#
#
#
# RT @Afgeezy97 : #DearSister I'll mix societal / cultural factors into Islam in order to silence & subjugate you & use actual Islam only when i ... :::: ['not_applicable']
#
#
#
# Avalon - Destined #DTBYIndakan https://t.co/3VYhghxLny :::: ['not_applicable']
#
#
#
# Hong Kong's slow economic growth and political divisions were beyond Beijing's expectations https://t.co/OaVdvx6tmo :::: ['not_applicable']
#
#
#
# RT @Alicekhj0606 : ( 11 . 02 17 ) 金賢重 Military Discharge ? https://t.co/F52PvzVYlE via @YouTube :::: ['not_applicable']
#
#
#
# RT @pinkeukisseu : Okay la bye kene sambung buat proforma kalau tk nanti 'Aishah perah lagi bye :::: ['not_applicable']
#
#
#
# RT @BTS_twt : https://t.co/b7HSgfmM7K\n # ? ? ? ~ https://t.co/du5UJlVSRS :::: ['not_applicable']
#
#
#
# RT @The5HVotes : We have reached the 1 million vote mark on Twitter . The second artist to do it ! #FifthHarmony #YouKnowYouLoveThem ... :::: ['not_applicable']
#
#
#
# RT @LifeFacts : This my dramatic ass ? ? https://t.co/AevtFQoK9d :::: ['not_applicable']
#
#
#
# taeyeon is as excited as us AHHHHHHHHHHHHH :::: ['not_applicable']
#
#
#
# RT @freaksingeeks : jovens que tao so ́ o james franco todos os dia https://t.co/FvT1NvO4JN :::: ['not_applicable']
#
#
#
# RT @AfifSyahmiii : U're 18 + already . Dont fall in love jst for fun . Be matured in relay . Its not time to play games , test mrket or easily let pp. .. :::: ['not_applicable']
#
#
#
# RT @LoyaltyIsFirst : " The impact of a book " https://t.co/Nrj7TNzS0o :::: ['not_applicable']
#
#
#
# RT @GordonRamsay : Yes a big tip throw it away .... https://t.co/engJpsooLR :::: ['not_applicable']
#
#
#
# D-6 ? @kli1106 :::: ['not_applicable']
#
#
#
# RT @shashaabbas : Simple words but have a great meaning . https://t.co/yYga5W2bY4 :::: ['not_applicable']
#
#
#
# RT @JoeyTribbiiani : Ed Sheeran sings FRIENDS Theme Song ? https://t.co/A2JjBjhL9q :::: ['not_applicable']
#
#
#
# RT @starshiplegends : y'all CAN'T call chaeyeon untalented . do you know how hard it is to have a perfect ending pose to a performance ? lo ... :::: ['not_applicable']
#
#
#
# #tila tequila nude lesbian video lebanon fuck hot https://t.co/7FzCDA0cVF :::: ['not_applicable']
#
#
#
# RT @Kiindasordaa : When y'all post food pics , say where you got it from . We family , ain't no secrets bih . https://t.co/pqZFiIr7Vp :::: ['not_applicable']
#
#
#
# https://t.co/NSMGev3xTU Coffin Princess Chaika : Complete Season Collection Blu-ray #Movies , #film , #trailers , #bl ... https://t.co/64AJtyE6Eq :::: ['not_applicable']
#
#
#
# hahahahahahahahaahahahahahahaha https://t.co/L2Ua3vloTN :::: ['not_applicable']
#
#
#
# RT @madhumacintosh : Who's this ? ? ? ? soooo good . ? https://t.co/9d6hnaQ4fy :::: ['not_applicable']
#
#
#
# RT @Advil : the gas / ice giants : Jupiter , Saturn , Uranus , Neptune ? http://t.co/Vb7yXaUVhH :::: ['not_applicable']
#
#
#
# RT @bangtanstan_07 : @Xiaxue Every celebrity is wearing make up . Men or women . Kpop or not . So what's the problem ? :::: ['not_applicable']
#
#
#
# https://t.co/ySQLHUEVbF Coup Rebellion G54 Anarchy https://t.co/YHOGVcCx9s #tweet #tradingcards , #tradingcard , #tradingcardgame , card gam ... :::: ['not_applicable']
#
#
#
# RT @risegfriend : is sinb okay https://t.co/3ec1yYM0HG :::: ['not_applicable']
#
#
#
# RT @Cho49a : 100 RETWEETS TO WIN 5 BIGBANG Made VIP #KCAFavGlobalMusicStar #BIGBANG :::: ['not_applicable']
#
#
#
# RT @cupcake_aisyah : be humble :::: ['not_applicable']
#
#
#
# @iskandar_z23 tired as fuuuuuuuuck :::: ['not_applicable']
#
#
#
# RT @LifelnWords : I want a 4.0 GPA , flat stomach , clear skin , balanced social life , 10 hrs of sleep each night & money in the bank :::: ['not_applicable']
#
#
#
# @ridobets use head one :::: ['not_applicable']
#
#
#
# RT @tbhjuststop : When you accidentally double tap someone's picture from 57 weeks ago https://t.co/B6IfNxZdd5 :::: ['not_applicable']
#
#
#
# RT @Twitch_Zagar : Though his body rests , his soul lives on . Rest in Peace Caesar Zeppeli . 2-27 -1939 https://t.co/zGd4dyp5ok :::: ['not_applicable']
#
#
#
# RT @Complex : Horrifying video shows teen jumping to his death in Snapchat stunt gone wrong https://t.co/UMotvNCo8i :::: ['not_applicable']
#
#
#
# RT @nazrhulflynex : Hi girls .. 5mins only please ? ? after that it's your own choice . https://t.co/5FSkupbiIw :::: ['not_applicable']
#
#
#
# RT @Ginmu1027 : #FFXV marshmallow https://t.co/pCxI8MRzzx :::: ['not_applicable']
#
#
#
# @sirotora3 @sakurairyuka 頑張ってない ！ うぷぷぷ 。 最近は暇なんでちょっとサボった www :::: ['not_applicable']
#
#
#
# I have more time now since I created the EA . I can trade not only for myself , but also for my friends and clients . https://t.co/fkPm5NJkQZ :::: ['not_applicable']
#
#
#
# RT @doublemacbo : what the heck u could run away from home but still be at home https://t.co/Nyaf3ibvlM :::: ['not_applicable']
#
#
#
# RT @idanurasella : Perempuan atau lelaki once dah curang , benda tu macam dah jadi hobi . :::: ['not_applicable']
#
#
#
# @_abibi_ here ? ? ‍ ♂ ️ ? ? ‍ ♂ ️ :::: ['not_applicable']
#
#
#
# @Firoen @YouTube my man :::: ['not_applicable']
#
#
#
# RT @irshadxx : @mxryjxne_ ? ❣ ️ https://t.co/vI06xOGECr :::: ['not_applicable']
#
#
#
# Im so tired already but im on morning again tmr ? :::: ['not_applicable']
#
#
#
# RT @demilovatobr : Ao que parece o novo single da Demi ja ́ foi escolhido e Charlie Walk , presidente da Republic Records , confirmou que ... :::: ['not_applicable']
#
#
#
# Grocery time @PochMendiola ? ? ? ? ? https://t.co/QfEAT7xa8W :::: ['not_applicable']
#
#
#
# Showcasing Hokkaido's charms @ Japan Food Town https://t.co/oWEHOw0m6v https://t.co/fxcXENj6N5 :::: ['not_applicable']
#
#
#
# 10 Digital Marketing Tools to Make Life Easier #marketingtools #marketingtips https://t.co/AAwe4dB1Cg https://t.co/4eEaezj5PT :::: ['not_applicable']
#
#
#
# RT @nathalieeparis : All I want to do is get away and travel the world :::: ['not_applicable']
#
#
#
# RT @Alyssa_Milano : YOU GUYS !!! Ukranian businessman with links to Donald Trump and Russia dies in unexplained circumstances https://t.co/hV ... :::: ['not_applicable']
#
#
#
# @ZalkaB Precisely . Understanding customers & their needs is critical to steer the ⛴ in the right direction ! :::: ['not_applicable']
#
#
#
# RT @MensHumor : ✌ ️ https://t.co/k02lgahtv1 :::: ['not_applicable']
#
#
#
# RT @bluebaby28 : Photobook #FLIGHTLOGARRIVAL #Mark https://t.co/iIkJfOxdmV :::: ['not_applicable']
#
#
#
# RT @101boys _ global : [ PIC ] YGK+ model Kwon Hyunbin has been spotted ! https://t.co/D2CkY1n3dd :::: ['not_applicable']
#
#
#
# RT @chantyxc : I'm telling y'all they're just beginning their road to success and they've accomplished so many already . Just watch . ? ? :::: ['not_applicable']
#
#
#
# RT @hellokimsohyun : 안돼용 ! #삼성증권 https://t.co/QtkXYpuUiQ :::: ['not_applicable']
#
#
#
# RT @halcyon1796 : 로라 웃을때 귀여우니까 많이 웃게 좀 해주지 https://t.co/wQ5S9errbd :::: ['not_applicable']
# RT @Beam_Mal : In the wildlands on the road to 200 on @Beam https://t.co/CDZhoECG0p #SupportSmallerStreams :::: ['not_applicable']
#
#
#
# I liked a @YouTube video https://t.co/H4GhAyyjAV DIL BURNS THE PANCAKES - Dan and Phil Play : Sims 4 # 36 :::: ['not_applicable']
#
#
#
# RT @BestEarthPix : The sea is gorgeous ? https://t.co/lTB1xjIw0m :::: ['not_applicable']
#
#
#
# And next month we get #China 's defense budget : #Trump to propose boosting defense spending $ 54 billion : aides say ... https://t.co/AZ3SWNRH9C :::: ['not_applicable']
#
#
#
# The moment you find time to pencil in some downtime , it's as i ... More for Scorpio https://t.co/X5Rgn0MtqF :::: ['not_applicable']
#
#
#
# RT @G_redcherry_B : 160826 아리오 아게오 \n#매드타운 #MADTOWN #버피 #BUFFY #주현 ❤ HQ https://t.co/U6HQTjXGuk\nhttps://t.co/BGkPDDh4sk ... :::: ['not_applicable']
#
#
#
# @fishupie OMG your favourite is catfish ! Wouldn't have expected that at all ! ? ? ? :::: ['not_applicable']
#
#
#
# okay din palang may binabalikan . haha :::: ['not_applicable']
#
#
#
# Isang iyak na lang , isang sakit na lang :::: ['not_applicable']
#
#
#
# RT @king_0615 : ㅋㅋㅋㅋ 나는 진지한 멋있는 리더다 자연스럽게 받을 줄 알았던 척 하자 https://t.co/HqNTOfZGEr :::: ['not_applicable']
#
#
#
# Dog Thinking https://t.co/UfINeSaDaN :::: ['not_applicable']
#
#
#
# #black shemale fucking guy romani porn https://t.co/qfCxJUmMHw :::: ['not_applicable']
#
#
#
# @LukeMozzicato you https://t.co/hJuZI9tbwf :::: ['not_applicable']
#
#
#
# RT @HidayahZakir : perjudian paling besar dalam hidup wanita https://t.co/vPQQdsFGh8 :::: ['not_applicable']
#
#
#
# RT @nobiprincess : omg tbh im kinda scared too pls take care maraming ano kasi huhu but also enjoy @lizasoberano ☺ ️\n\n #LizaSoberano ... :::: ['not_applicable']
#
#
#
# RT @MediShield15 : Claim back up to $ 500 for Approved Course attended . @SkillsFutureSG https://t.co/YyoiVelKaN! Many Paid for Course ... :::: ['not_applicable']
#
#
#
# RT @ItsFoodPorn : Garlic Shrimp Pasta ? https://t.co/yxLXQZmIVM :::: ['not_applicable']
#
#
#
# So @VodafoneIN is in a hissy fit as I leave the network for @Airtel_Presence . I hope @Airtel_Presence knows what I am going through for it ! : P :::: ['not_applicable']
#
#
#
# @Mr2046 Heard the story that the club couldnt get approval for his work permit .. :::: ['not_applicable']
#
#
#
# RT @ch0sshi : 2nd card ㅡ continue to look forward to things more . everything , no matter what i do . it all starts through you guys . :::: ['not_applicable']
#
#
#
# RT @Gaemers0302 : #Kyuhyun #규현 #OneVoice_NagoyaDay2 song request #Inoo #GodOfWarOST https://t.co/4wTeqLns53 :::: ['not_applicable']
#
#
#
# @tnsquinMY Listen to You Don't Think You Like People Like Me by Alex Lahey or Don't Leave by Snakehips and M ø :::: ['not_applicable']
#
#
#
# @CoopTWD follow @LittleNeesh you owe her one for like ignoring her request for a follow through out the stream :::: ['not_applicable']
#
#
#
# Please tweet your birthday greetings for Tanochan with the tag #田野優花生誕 ! She's turning 20 on 7th March ( in 50 mins !... https://t.co/TMZYhqiWoo :::: ['not_applicable']
#
#
#
# RT @_taekooks : ireumeun jungkook #ARMYSelcaDay https://t.co/ksobPF0j6B :::: ['not_applicable']
#
#
#
# [ PD 를 만나다 ③ ] ' 보이스 ' 김홍선 PD "시즌 2 , 충분히 가능하다"\n출처 : 스포츠동아 | 네이버 TV 연예\n https://t.co/mwgYpeJGyQ YAS ? :::: ['not_applicable']
#
#
#
# as empresas sao sempre assim acontece alguma merda c a saude do idol e eles vem com a maior cara lavada falando que vao prestar +atencao :::: ['not_applicable']
#
#
#
# RT @Squawka : Xabi Alonso has won 16 major trophies during his career , including : Champions League ? ? European Championships ? ? World Cup ? ... :::: ['not_applicable']
#
#
#
# @UmeuMeumE_Y お誕生日おめでとうございます ！ ！ :::: ['not_applicable']
#
#
#
# RT @ZakWxxx : ➡ . __ https://t.co/hU3btSTMUj __ . ⬅ https://t.co/SyTWFQkfnO https://t.co/ksWiLJ1tbQ :::: ['not_applicable']
#
#
#
# There isn't much that can shake your allegiance once you decid ... More for Leo https://t.co/voCGM3Yqje :::: ['not_applicable']
#
#
#
# RT @B2STera : [ OFFICIAL ] Highlight #하이라이트 Official Youtube Channel is now opened ! Subscribe it now at : https://t.co/EXl5sxozhG ... https : // t .... :::: ['not_applicable']
#
#
#
# RT @9GAGGifs : Woops AHAHAHA .... https://t.co/rj0VB5l9rp :::: ['not_applicable']
#
#
#
# #pregnet naked woman boyfriend wont have sex with me https://t.co/QB8ut72tfT :::: ['not_applicable']
#
#
#
# RT @topislamictwit : Before anything or anyone , even yourself https://t.co/bkW4fyEskY :::: ['not_applicable']
#
#
#
# When will the day come where I have to officially dye my hair black . :::: ['not_applicable']
#
#
#
# Haircut checked ✅ https://t.co/VWAoma4xQj :::: ['not_applicable']
#
#
#
# first star thank god :) :::: ['not_applicable']
#
#
#
# Suicidal and depressed , Amanda tells us how it is to have these haunting thoughts . https://t.co/BwCYQsX1IZ :::: ['not_applicable']
#
#
#
# RT @Mooinjust5secs : Everyone ~ Meet Sechskies' Kang Sunghoon's long lost daughter LMAOOO https://t.co/Wj0pXruj6k :::: ['not_applicable']
#
#
#
# A rather ominous use for #AI but necessary . " Facebook Uses Machine Learning To Spot Suicidal Users https://t.co/kSBpfSKaan #social " :::: ['not_applicable']
#
#
#
# IM SAFE THANK GOD TECHNOLOGY ISNT THAT ADVANCED YET :::: ['not_applicable']
#
#
#
# RT @girlstreamers : ? Vote ? @watch_ezilii https://t.co/8r2iouuV6P @twitchretweetr @Twitchsharer :::: ['not_applicable']
#
#
#
# @nuriraa_ *work week :::: ['not_applicable']
#
#
#
# https://t.co/ySQLHUEVbF Ultra Pro 50 Standard Size Deck Protectors Box Light Blue Case Of 12 https://t.co/8kpNsNi8cZ #tweet #tradingcards ... :::: ['not_applicable']
#
#
#
# OMG ! You have to see this . #BIGOLIVE . https://t.co/duE2gcQzec https://t.co/jNekJl6dWq :::: ['not_applicable']
#
#
#
# Gotcha .... #supper #mum https://t.co/nNwiXlxbcO :::: ['not_applicable']
#
#
#
# https://t.co/eBgzQQzfwt :::: ['not_applicable']
#
#
#
# RT @alessiasyndrome : I hope the mainstream media or film industry doesnt change this little pure ball of sunshine https://t.co/Ks1kqR6MS0 :::: ['not_applicable']
#
#
#
# よくばりなんです 。 :::: ['not_applicable']
#
#
#
# Yep . I contacted them already :::: ['not_applicable']
#
#
#
# European Firms Planning to Build ' Energy Island ' In North Sea to Provide Cheap Wind Power to Tens of Millions ... https://t.co/0dKtUVy4kT :::: ['not_applicable']
#
#
#
# RT @Fullyfetch : @priya036 happy birthday ! Have a great day ☺ ️ :::: ['not_applicable']
#
#
#
# RT @SkinsGifs_ : https://t.co/yDCzk1AEfc :::: ['not_applicable']
#
#
#
# You're thinking at the speed of light and you're ready to make ... More for Cancer https://t.co/SVvNEafNr9 :::: ['not_applicable']
#
#
#
# RT @GENIC0N : centrism feels like radicalism when you don't actually know what radicalism feels like https://t.co/IoacVBtaCH :::: ['not_applicable']
#
#
#
# RT @xnejane : the fan randomly played 3 keys on the piano and yixing improvised beautiful melody out of them ;; https://t.co/M9WxOsIfpK :::: ['not_applicable']
#
#
#
# RT @usagiyakuro : 東方レースクイーン 魔理沙\nパンツはうしじまさん @PredatorRat の超超ローライズ ? \n#東方 Project #コスプレ #cosplay https://t.co/z3X9w7PAJj :::: ['not_applicable']
#
#
#
# Guide to Top Art Events in Hong Kong this March https://t.co/1T8cOq5xeT via @butterboom :::: ['not_applicable']
#
#
#
# RT @f4mmedia : Content , Design , Styles - Marketing - 2017 - 9 https://t.co/YrAenwDF58 :::: ['not_applicable']
#
#
#
# RT @nyzamskrr : riot ? nobody gonna waste time to fight for underage smokers https://t.co/nzbQtzVJOb :::: ['not_applicable']
#
#
#
# Just posted a photo @ Harbour City https://t.co/UHKcEDNnLE :::: ['not_applicable']
#
#
#
# Someday it will rain :::: ['not_applicable']
#
#
#
# 하이라이트 ( Highlight ) 1st Mini Album ` CAN YOU FEEL IT ? ` HIGHLIGHT MEDLEY https://t.co/VtDE5N59jU :::: ['not_applicable']
#
#
#
# RT @6thvisual : Nak mataer smpai Kahwin and ke jannah InsyaAllah :::: ['not_applicable']
#
#
#
# RT @LaughingSpartan : I miss McDonald's , fast food restaurant . Now it's McDonald's , polyclinic . https://t.co/Fg8m2suRJr :::: ['not_applicable']
#
#
#
# Wow ... purple economics ! In the U . K . the potential spending power of people with disabilities is being ... https://t.co/9K8d8qCgzh :::: ['not_applicable']
#
#
#
# RT @charlieputh : Love this Jungcook https://t.co/mvo82WAOLR :::: ['not_applicable']
#
#
#
# WTF !!! :/ https://t.co/5u2eQ3AUUZ :::: ['not_applicable']
#
#
#
# BWF-PS course ✔ ️ been a fruitful 2 weeks . Learnt a lot from the ... https://t.co/5hdsUIJJPC :::: ['not_applicable']
#
#
#
# RT @vyakaran : Gujarati playwright Taarak Mehta dies at 87 https://t.co/274JoTXkXf :::: ['not_applicable']
#
#
#
# DINNER MAINS-GRILLED RIBEYE STEAK-WITH ROASTED KIPFLER , PORTOBELLO & WILTED SPINACH WITH TRUFFLE HOLLANDAISE :::: ['not_applicable']
#
#
#
# Rebecca Ruiz - Here's how you create echo chambers on Facebook https://t.co/j7v4wvpPST :::: ['not_applicable']
#
#
#
# kimk nak wish org birthday pun susah :::: ['not_applicable']
#
#
#
# RT @IFIEYYRAFAA : you once made me happy & i'm thankful for that . :::: ['not_applicable']
#
#
#
# RT @yeenshzreen : @officialJiji im just asking just now kot ????? mende yg gelabahnya . lahai :::: ['not_applicable']
#
#
#
# @SuzukiSuzume いい推し事\n\n sg got cow tongue anot ah lol :::: ['not_applicable']
#
#
#
# Khatib Jumaat hari ini ialah Ustaz Dr Feirul Maliq dan Bilal Hj Musafa Kasbi #almuttaqinlive #bismillah https://t.co/6Ya80XrM1h :::: ['not_applicable']
#
#
#
# @RusyaidiBMZ SIAPA LAIN KENA 12 MAY ? :::: ['not_applicable']
#
#
#
# 1-hour PM2 . 5 concentration at 6am is 4-12 microgram per cubic metre . https://t.co/SSxmKM8mF0 #sghaze :::: ['not_applicable']
#
#
#
# @scanikoniko さくりこーちゃん~~\nハッピーバースデー ！ ！ ? ? ? ? ✨ :::: ['not_applicable']
#
#
#
# RT @Study_INTNL : #SoutheastAsia 's fierce growth of private international schools https://t.co/ftSsLVaiH9 https://t.co/bpEbAsxckn :::: ['not_applicable']
#
#
#
# RT @asonofapeach : Cool . https://t.co/aZEGzY4jvO :::: ['not_applicable']
#
#
#
# https://t.co/2ifHoPz401 Mark XLIII Battle Damaged Version and Hulkbuster - Artist Mix Marvel Collectible Set https://t.co/eY05N2vbYs #twe ... :::: ['not_applicable']
#
#
#
# RT @9GAGGifs : Maybe he has some issues ... https://t.co/a0dwk8FpK5 :::: ['not_applicable']
#
#
#
# Light & Composition Prime - https://t.co/MNLQ2vwcJN - https://t.co/KzDvPjoz1o :::: ['not_applicable']
#
#
#
# China Sends Praise And A Warning To India's Modi https://t.co/xKQAaruct7 #forbes https://t.co/CljumcT6hm :::: ['not_applicable']
#
#
#
# RT @ObamaMalik : Free Kekistan ! :::: ['not_applicable']
#
#
#
# RT @pjmhopes : they deadass did that pose im https://t.co/psjkU5mGP5 :::: ['not_applicable']
#
#
#
# RT @bellathorne : Hahahahahah do you do you ? https://t.co/o3BM3edPAO :::: ['not_applicable']
#
#
#
# I think taking this long ass break showed me my priorites , which I have trouble with . :::: ['not_applicable']
#
#
#
# RT @ItsFoodPorn : Peanut Butter Nutella Candy Bar Brownies ? https://t.co/pSsJdawevC :::: ['not_applicable']
#
#
#
# RT @Zoella : LOVED THIS ! ? ? ♥ ️ https://t.co/FGySHxPqaz :::: ['not_applicable']
#
#
#
# ...
#
#
#
# Secondary schools will never be the same https://t.co/3FRhy40WFl :::: ['not_applicable']
#
#
#
# RT @xavierlur : Who else always press for a new straw even though there's already a straw because scared dirty ? ? https://t.co/hNnhpGUgAL :::: ['not_applicable']
#
#
#
# OMG ! You have to see this . #BIGOLIVE > | ? List . https://t.co/iMulZ5JpoW https://t.co/EBIZ5CHngP :::: ['not_applicable']
#
#
#
# RT @insehunity : ? SG FANS ! LAST CALL ? ONE Prod has agreed to accept the book from us ! Send in your birthday messages for Sehun by 1 March 2 ... :::: ['not_applicable']
# RT @pakalupapito : it's my goal to be this calm when things are falling apart https://t.co/UCRuloyVIh :::: ['not_applicable']
#
#
#
# RT @Zef420024feZ : My bro @WhiteWolfandOwl is live on #twitch now go check him out lol #SupportSmallStreamers @TwitchSharer https://t.co/r ... :::: ['not_applicable']
#
#
#
# @DrakeMoon https://t.co/uodPooneau :::: ['not_applicable']
#
#
#
# Sinarmas Land Limited - Demand expected to improve ■ Development sales in FY16 met 91 % of the Group's full year ... https://t.co/RGX5tqoSxw :::: ['not_applicable']
#
#
#
# RT @Slate : La La Land is on a run . Here's the full list of winners tonight : https://t.co/IT0i3T7DiZ #Oscars :::: ['not_applicable']
#
#
#
# RT @laurDIY : 10 : 30PM : ok time for bed 2AM : *has watched 45 youtube videos , lurked everyone from highschool and re-organized my phone* :::: ['not_applicable']
#
#
#
# was craving fr mcd and yay craving satisfied thx friends hehe :::: ['not_applicable']
#
#
#
# RT @Lasmolinas7910 : " Those who protect and save other animals lead the way in protecting and saving humanity and earth " #Gustavito https : // ... :::: ['not_applicable']
#
#
#
# RT @Iifepost : THIS IS SO CUTE , I WISH MY DOG ENJOYED BATHS https://t.co/DhmK7LiUQs :::: ['not_applicable']
#
#
#
# RT @edsheeran : It's out ! Bloody hell that feels good to say . Tune into Chris Evans this morning on radio 2 , doing a session , then the one ... :::: ['not_applicable']
#
#
#
# Attend our next #seminar on #forextrading for FREE ! Visit our website : #Forex #ForexNews #Dubai #ForexTraining #fx https://t.co/gEz6qlMgwf :::: ['not_applicable']
#
#
#
# Something about night walks https://t.co/xeWdQqcb6Y https://t.co/WxUzW2cYb0 :::: ['not_applicable']
#
#
#
# RT @ASAPOFFICIAL : Fresh faces ! PBB Lucky Season 7 's Vivoree , Elisse , and Cora ! #ASAPMarSorpresa ☀ ️ https://t.co/0MB0HmxjpD :::: ['not_applicable']
#
#
#
# RT @DamnFeelings : The 3 rules of a relationship : Don't lie , don't cheat , and don't make promises you can't keep . :::: ['not_applicable']
#
#
#
# Yeah . I'm bored . Ended up with a ThaHaan doodle dump . ✏ ️ https://t.co/BLtkO3hkoi :::: ['not_applicable']
#
#
#
# RT @thewomanjewelry : " Brand Design western style Multilayer Pendants " Only $ 19 . 75 ! USA FREE SHIPPING . GET YOURS HERE == > ... :::: ['not_applicable']
#
#
#
# Back to work after hols = ? :::: ['not_applicable']
#
#
#
# And if the background is black the pictures on the cards will just end up looking like shit ? :::: ['not_applicable']
#
#
#
# 3 MORE !!!!!!!!!!!!!!!! :::: ['not_applicable']
#
#
#
# AA A A A AA https://t.co/sK7pKOymCn :::: ['not_applicable']
#
#
#
# @nielwong I seriously doubt they are in any hurry to leave Malaysia :::: ['not_applicable']
#
#
#
# RT @Nampaikid : she kept pretending it hurt to scare her dad ? ? ? ? ? https://t.co/ohn1cGwBGs :::: ['not_applicable']
#
#
#
# RT @knowledge_onlyy : ? ทะเลเรือนแสง ( Bioluminescence ) เกิดการเรืองแสงได้จากแพลงก์ตอนที่ทำให้เกิดการเรืองแสง แพลงก์ตอนกลุ่ม ไดโนแฟลกเจลเลต ... :::: ['not_applicable']
#
#
#
# RT @ARMYChile : La fansite @hopeplus0218 estara ́ desde las las 3.30 pm vendiendo sus slogan en el stand de ARMY CHILE . https://t.co/d2VZOJdX0Y :::: ['not_applicable']
#
#
#
# RT @ChannelNewsAsia : Republican backlash over Trump-backed healthcare bill https://t.co/r2BLJygipL :::: ['not_applicable']
#
#
#
# RT @heros3377 : confirmed https://t.co/DFVPWYk0tQ https://t.co/o4sNzRSBaW :::: ['not_applicable']
#
#
#
# OMGNSNSH I CANT WAIT https://t.co/Z3PnWRgU8V :::: ['not_applicable']
#
#
#
# Am I one of the only few who notices how epic Commentator Ray Hudson is when he makes remarks on La Liga matches , esp when Messi scores ? :::: ['not_applicable']
#
#
#
# @nikiakila tamp giant !!?? :::: ['not_applicable']
#
#
#
# @ofmeowandbake i sign up more for USS and SEA . Lol :::: ['not_applicable']
#
#
#
# Yo wtf I can't do mendes measure 26 :::: ['not_applicable']
#
#
#
# YouTube Rewind : Turn Down for 2014 https://t.co/LUi66PTkoO :::: ['not_applicable']
#
#
#
# RT @Timbo_Slice1991 : Not letting black people on Paris trains is more embarrassing https://t.co/I8C9ZmjPaL :::: ['not_applicable']
#
#
#
# @fr1zzledy flattened ! :::: ['not_applicable']
#
#
#
# RT @ohgirIquotes : look how easy that is !! all u have to do is communicate with me . communication is the key . https://t.co/EUWnxKf7DN :::: ['not_applicable']
#
#
#
# @wdurrahh depends location :::: ['not_applicable']
#
#
#
# RT @SopanDeb : Incredible work here by @EricLiptonNYT : https://t.co/K9T0yz6Lgv https://t.co/9xqVACOeck :::: ['not_applicable']
#
#
#
# RT @daaaaa___s : @chanyeolit 릿님 드디어 포토북이 도착했습니다 !!! 사진들도 너무 이쁘고 특전들도 다 예뻐요 특히 트럼프카드 정말 최고입니다ㅠㅠㅠㅠㅠ 항상 예쁘고 멋진 찬열이모습 카메라로 담아주셔서 감사합니다 ❤ ️ https : // ... :::: ['not_applicable']
#
#
#
# AIGOOOO CUTE https://t.co/Htreh5uLpV :::: ['not_applicable']
#
#
#
# @suburban_homo besides the fact that I lack a beachside body ... Lets go ! :::: ['not_applicable']
#
#
#
# I just saw a girl skipping in the heavy rain . I think I found my soulmate HAHAHAHA ? :::: ['not_applicable']
#
#
#
# Yeay can't wait for good food tmrw ? :::: ['not_applicable']
#
#
#
# RT @Sounderstylish : காவிங்களுக்கு அதிமுக மேல கோபம் வராது ... திமுக னா மட்டும் என்னாமா காண்டு ஆவுறானுவ That's enough ? ? :::: ['not_applicable']
#
#
#
# Hey Mira Tzur https://t.co/3qUZUKOr4c thanks for the follow ! :::: ['not_applicable']
#
#
#
# RT @amenGreens : don't say a word when i chest kick your daughters https://t.co/bm4UacSucn :::: ['not_applicable']
#
#
#
# RT @kosherjellyfish : Giordano what is this https://t.co/TxZ6YaVspL :::: ['not_applicable']
#
#
#
# The race to produce batteries for electric vehicles has set off , in right earnest . Demand may surge humoungously ! :::: ['not_applicable']
#
#
#
# RT @NCTsmtown : [ NCT LIFE MINI ] #윈윈 과 #천러 누가 더 한국말을 잘 하나요 ? #쟈니 가 인터뷰 해 봤습니다 . 결론은 , 둘 다 잘한다고 하네요 ? https://t.co/4F49xzS5BZ :::: ['not_applicable']
#
#
#
# shoot ilight with film and maybe anamorphic https://t.co/Jxdb7geBYp :::: ['not_applicable']
#
#
#
# @WorldBank interesting but in itself doesn't tell us anything . #Internet is not education . What are they accessing on the net ? :::: ['not_applicable']
#
#
#
# RT @notacrime0802 : [ GIF ] #MARK #마크\n애깅아\n ( https://t.co/CXYynQnkEv ) https://t.co/dQDbXPJqcz :::: ['not_applicable']
#
#
#
# back at sg :::: ['not_applicable']
#
#
#
# How to keep your app users from dumping you https://t.co/vPhxz6HM4K :::: ['not_applicable']
#
#
#
# @khynsrn congrats and thabks for the invitation ! Hahah just kidding ! Happy wedding khai ! :::: ['not_applicable']
#
#
#
# Annoyed . Coursera app didnt display due dates for some assignments properly . No reminder notifications worked . Now i have so many overdue . :::: ['not_applicable']
#
#
#
# RT @rasoolrashford : am i the only one who feel naked without a watch on my hand ? :::: ['not_applicable']
#
#
#
# https://t.co/2ifHoPz401 Predator - Masked Hunter Predator Legendary Scale ( TM ) Bust https://t.co/fQh8Owki4A #tweet #collectibles #toys #mo ... :::: ['not_applicable']
#
#
#
# what do you mean you dont have green tea without sugar https://t.co/vKRhXZIaTP :::: ['not_applicable']
#
#
#
# [ STREAM & WIN ] BABYZ ! Have you joined in our Wake Me Up MV streaming giveaway ? It's opened internationally ! https://t.co/9xpurSBI0t :::: ['not_applicable']
#
#
#
# RT @BestMMAnews : " I will have my vengeance soon " - Yoel Romero on Michael Bisping vs . Georges St-Pierre booking . #BJPenn #UFC https://t.co/ ... :::: ['not_applicable']
#
#
#
# #lacie heart porn video man fucking girls in bush-pictures https://t.co/DLBUAiINFQ :::: ['not_applicable']
#
#
#
# RT @MacCollinsBooks : Beat those #MondayBlues with one of our great range of children's books ! https://t.co/dvxjTKyWxo :::: ['not_applicable']
#
#
#
# RT @CCA_HOOPS : Girls beat Lutheran East in the District Finals 55-38 ! #road2states :::: ['not_applicable']
#
#
#
# RT @EvanMarkoh : do u ever look at someone and just pray to god u never have to lose them :::: ['not_applicable']
#
#
#
# If websites are people I want to kick tigerair's website in the butt :::: ['not_applicable']
#
#
#
# @daseotbyul where where ? :::: ['not_applicable']
#
#
#
# E amanha ̃ de manha ̃ me ́ dico outra vez ? :::: ['not_applicable']
#
#
#
# RT @allkpop : Kwanghee suggests EXO's Suho as his replacement on ' Infinity Challenge ' https://t.co/w1kk6iixcK https://t.co/A6LOBQYDUO :::: ['not_applicable']
#
#
#
# RT @Gemini_A7 : If you need reassurance , you go to #Gemini . :::: ['not_applicable']
#
#
#
# RT @drugvisual : just wanna do bad things with the right person :::: ['not_applicable']
#
#
#
# RT @1followernodad : wait til he learns about Honey Roasted Parent Hood :::: ['not_applicable']
#
#
#
# RT @852WANG : GOT7 Schedule Feb - May ( With Comeback Plan ) https://t.co/Ivqp3wSKL5 :::: ['not_applicable']
#
#
#
# @Jeaseanjore nope ... Using iPad with wifi now :::: ['not_applicable']
#
#
#
# RT @YouTube : @danisnotonfire What in video modification :::: ['not_applicable']
#
#
#
# Study High - THE EYE : interesting perspective from SAS journalists about the lengths kids will go to to succeed . https://t.co/ZH7USSWX8E :::: ['not_applicable']
#
#
#
# RT @MaxJr617 : That aiming was on point ? https://t.co/E6n8CdTI8B :::: ['not_applicable']
#
#
#
# Why r the lifts always so slow on saturdays :::: ['not_applicable']
#
#
#
# RT @oilysailor : Walcott now has more CL goals than ? ? Ronaldo and Zinedine Zidane :::: ['not_applicable']
#
#
#
# @AshKyd dead letter circus maybe ? :::: ['not_applicable']
#
#
#
# Williams has had to abandon the second day of 2017 Formula 1 testing after just 12 laps due to damage incurred when ... https://t.co/F0110Ex9Ue :::: ['not_applicable']
#
#
#
# RT @YesuActorHost : I have watched #MyExAndWhys 7 times now . 1st was on our Premiere Night and latest Full house in Bataan . ? Tell me bakit ... :::: ['not_applicable']
#
#
#
# RT @jimmykimmel : Hey @realDonaldTrump u up ? :::: ['not_applicable']
#
#
#
# RT @VirgoNation : Acting like you don't care only forces a #Virgo to really not care . :::: ['not_applicable']
#
#
#
# RT @homotears : Amber is kinda spilling some tea about SM and she might probably leave or hinting f ( x ) disbandment . im so mad https://t.co/y ... :::: ['not_applicable']
#
#
#
# RT @Cdesarts : #Actualite ́ Disparition de Spencer Hays , ge ́ ne ́ reux donateur du @MuseeOrsay https://t.co/53BhEFX3Fj https://t.co/p9ltdueqq0 :::: ['not_applicable']
#
#
#
# @louisarcastiz olha que eu pec ̧ o mesmo viu ?! ? ? ? obrigada linda , na ̃ o sei fazer packs , mas se precisar de alguma coisa , estou aqui :::: ['not_applicable']
#
#
#
# RT @NotesForGirlz : let a man look at me like this ..... i'd be sinning for days https://t.co/8N4FjvXZYc :::: ['not_applicable']
#
#
#
# Morning Hyun Joong Gday For You ^^ ♡ #WelcomeBackKimHyunJoong #김현중_전역 #ProudToBeKHJfan #neverleavekhj @angee323818 ... https://t.co/ZDWs2XqTBI :::: ['not_applicable']
#
#
#
# RT @chobomvelvet : This Feb 10th 1994 line really love art .. ? #PinkVelvet #Apink #RedVelvet #에이핑크 #레드벨벳 https://t.co/njQ2Ui0l3v :::: ['not_applicable']
#
#
#
# #NowPlaying Prodigal by OneRepublic ♫ https://t.co/gkrdSgvWHk :::: ['not_applicable']
#
#
#
# This openly gay football player is about to make history https://t.co/hCbu9JFtoF https://t.co/kROZVoomFQ :::: ['not_applicable']
#
#
#
# https://t.co/NSMGev3xTU James Bond Octopussy DVD #Movies , #film , #trailers , #bluray , #dvd , #tv , #Comedy , #Action ... https://t.co/XtGo4inha4 :::: ['not_applicable']
#
#
#
# Hohoho . These Android cats are sho cute . https://t.co/l15PSjtOv0 :::: ['not_applicable']
#
#
#
# @salliestrawberi macam best jeeee thai masseuse :::: ['not_applicable']
#
#
#
# I'm at anyleynr's crib https://t.co/WDa5MYriHQ :::: ['not_applicable']
#
#
#
# RT @sayaOaO : （ セリフがはくおーきパロです ） 某氏の二番煎じです 。 光忠の眉間のシワが見たかったから ・ ・ ・ こわっ https://t.co/2flbstenW6 :::: ['not_applicable']
#
#
#
# RT @9GAG : Listen here Hagrid you FAT OAF ! I'm not a WIZARD ! https://t.co/E1n2gRK3Tn https://t.co/IL8PqajApX :::: ['not_applicable']
#
#
#
# @mim20_ Hahahah . It's 'Chamiya - Dulhan Hum Le Jayenge' :::: ['not_applicable']
#
#
#
# emo phase , back at it again :::: ['not_applicable']
#
#
#
# Selling 2 in 1 MAC Loose Eyeshadow Pigment S $ 18 https://t.co/QadSl8iaKW #carousell @thecarousell :::: ['not_applicable']
#
#
#
# RT @DJLOVE_SNO : Thank-you Singapore ! https://t.co/GugJEXDTE0 :::: ['not_applicable']
#
#
#
# RT @HanabiHun : L'Optimum タイ 3 月号セフン表紙購入フォームオープンします 。 こちらは日本の方です ? https://t.co/WLCRqFZjMk\n 注意 ⚠ 数に限りあります\n#세훈 #セフン #Sehun https://t.co/HLZmCEnmqC :::: ['not_applicable']
#
#
#
# RT @TumblrsFunnies : https://t.co/89zZILwAS5 :::: ['not_applicable']
#
#
#
# RT @STcom : Will the CYCLE of independent services continue to RIDE up in Singapore ? https://t.co/rBjcIKafVs :::: ['not_applicable']
#
#
#
# @lovekpopright Hehe aniya ? Actually I really want to sing that song with yixing during concert but he isn't coming ... so I thought of this ^^ :::: ['not_applicable']
# RT @wanderingmeekay : She loves the bread , she loves the burger . Most of all , you love each other . Charot ! Take heed ankol . ? ... :::: ['not_applicable']
#
#
#
# RT @joker_budou : 頭がおかしくなっちゃう ... https://t.co/Qpq6mt76CA :::: ['not_applicable']
#
#
#
# RT @camilacabello97 : #HeyMa from @FastFurious is out now ! tune into @UnNuevoDia tomorrow morning for the video premiere #F8 ... :::: ['not_applicable']
#
#
#
# RT @rapmonpictures : https://t.co/DkNPUuO506 :::: ['not_applicable']
#
#
#
# @Deannadarwina 2 maybelline and 2 australis . the australis one not good :( :::: ['not_applicable']
#
#
#
# RT @danisnotonfire : @AmazingPhil he failed https://t.co/HzQHwoVAmK :::: ['not_applicable']
#
#
#
# RT @THUYARAM : அசத்திட்டாப்ல ? ? ? ? https://t.co/xhHb0FeajC :::: ['not_applicable']
#
#
#
# TELEMARKETER - AXA INSURANCE PTE LTD https://t.co/HXzk3H98xv https://t.co/NB7Wtur0zn :::: ['not_applicable']
#
#
#
# RT @faliqfahmie : Warga JB , kami perlukan bantuan sesiapa yg mempunyai darah A+ , utk membantu ayahanda @KamilPhatman yg kini berada di Puter ... :::: ['not_applicable']
#
#
#
# trap song ? ? ? :::: ['not_applicable']
#
#
#
# will there be no bbh birthday party , or will he have one earlier ? i hope that kpop show airs on tv ; ~ ; :::: ['not_applicable']
#
#
#
# RT @mediacrooks : Can you show me some of the death and rape threats ? Or you have any evidence of phone calls or emails ? https://t.co/4fgjNv ... :::: ['not_applicable']
#
#
#
# @b33toTPF @ab33croft crowbar now this :::: ['not_applicable']
#
#
#
# RT @jeffteper : NEWS : #SharePoint News from your sites ( created with our new authoring experience + #SPFX ) comes to SharePoint Home https : // ... :::: ['not_applicable']
#
#
#
# RT @FreddyAmazin : People like this piss me off https://t.co/uSRvMleq6w :::: ['not_applicable']
#
#
#
# RT @imexosgf : ? 170228 [ FROM SUHO ] " junmyeonnie who is very excited to go to switzerland " ? https://t.co/RqTK7Y1H5q :::: ['not_applicable']
#
#
#
# RT @BBCAMERICA : 1 : 42pm is scientifically-proven to be the most stressful time of day . We're here to help ! Here's some #RealHappiness from # ... :::: ['not_applicable']
#
#
#
# RT @ChannelNewsAsia : 4 men arrested over St James Power Station murder https://t.co/oi5TGVYEdz :::: ['not_applicable']
#
#
#
# #SteadyAscentAteneo #OBF https://t.co/m3VCicCeOf :::: ['not_applicable']
#
#
#
# Get dinner / supper at 11pm be home at midnight and watching movie while waiting for food to be processed :::: ['not_applicable']
#
#
#
# " An Early Spring " by KATHERINE SCHULTEN via NYT https://t.co/NJTZ0cjUBz :::: ['not_applicable']
#
#
#
# how many more golden dragons must I slay ... :::: ['not_applicable']
#
#
#
# RT @azlanshahazamy : Me pergi kerja VS me balik kerja https://t.co/8nHjV5CDoM :::: ['not_applicable']
#
#
#
# Do Your Thoughts Matter ? #forex #forextrading #ForexMarket #ForexTradingTraining #ForexTradingTutorial ... https://t.co/6ybqJMSR0o :::: ['not_applicable']
