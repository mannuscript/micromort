# %%
import pandas as pd

# %%
labelled_data = pd.read_csv("/home/mannu/code/work/micromort/data/figure8/cf_report_1265970_full.csv")
labelled_agg_data = pd.read_csv("/home/mannu/code/work/micromort/data/figure8/a1265970.csv")

# %%
print labelled_data.shape
print labelled_agg_data.shape
# Out:
# (189, 5)
# (103, 11)

# %%
labelled_data
# Out:
#              id check_one_or_more  \
# 0    3717573034            health
# 1    3717497047            health
# 2    3717504158            health
# 3    3717571678            health
# 4    3717590772       environment
# 5    3717577475    safetysecurity
# 6    3717583932    not_applicable
# 7    3717577460       environment
# 8    3717583915    not_applicable
# 9    3717573031            health
# 10   3717465184    not_applicable
# 11   3717465741    not_applicable
# 12   3717495553            health
# 13   3717511252            health
# 14   3717590745    not_applicable
# 15   3717495550    not_applicable
# 16   3717511270    not_applicable
# 17   3717590761         economics
# 18   3717495549            health
# 19   3717511275            health
# 20   3717573032    safetysecurity
# 21   3717456275            health
# 22   3717498006            health
# 23   3717610597            health
# 24   3717573037          politics
# 25   3717494072          politics
# ...

# %%
labelled_agg_data
# Out:
#        _unit_id  _golden  _unit_state  _trusted_judgments   _last_judgment_at  \
# 0    1727665454    False  in progress                   1                 NaN
# 1    1727665455    False    finalized                   3  5/31/2018 10:30:27
# 2    1727665456    False  in progress                   1                 NaN
# 3    1727665457    False  in progress                   2  5/31/2018 10:35:44
# 4    1727665458    False  in progress                   2  5/31/2018 10:35:44
# 5    1727665459    False  in progress                   1                 NaN
# 6    1727665460    False  in progress                   2  5/31/2018 09:11:53
# 7    1727665462    False  in progress                   2  5/31/2018 09:50:48
# 8    1727665464    False  in progress                   1                 NaN
# 9    1727665465    False  in progress                   2  5/31/2018 09:50:48
# 10   1727665466    False  in progress                   1                 NaN
# ...
