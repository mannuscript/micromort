# %%
import pandas as pd
import folium
import pycountry
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os

# %%
mpl.rcParams['font.size'] = 15.0
labels = ["user.location", ""]
sizes = [24947, 26261, 45681, 52553, 5557]
labels = ["Business Times", "Today Online", "Channelnewsasia", "Straits Times", "Asiaone"]
#explode = (1, 1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%2.1f%%',
        shadow=False, startangle=90, labeldistance=1)
#ax1.axis('unequal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig1 = plt.gcf()
fig1.set_size_inches(6,6)
plt.show()

# %%
article_history = pd.read_csv("/home/mannu/Downloads/article_social_media_shares_history_dump.csv", delimiter="\t")

# %%
url_ids = article_history.url_id.unique()

# %%
for url_id in url_ids:
    dates = article_history[article_history.url_id == url_id].created_at
    dates.min()
    dates.max()
# Out:
# 94436

# %%
a = article_history[article_history.url_id == 4759471][article_history.social_media_channel == "Facebook_comment_count"]
a_dates = []
for d in a.created_at.values:
    a_dates.append(pd.to_datetime(d).date())
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
b = article_history[article_history.url_id == 14647916][article_history.social_media_channel == "Facebook_comment_count"]
b_dates = []
for d in b.created_at.values:
    b_dates.append(pd.to_datetime(d).date())
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
15011282
14647406
15011255
14647916
 1961006
18171554
 4339552
15066389
17671781
 4759471
# Out:
#   File "<ipython-input-74-da496a85511d>", line 5
#     1961006
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
plt.plot(dates, a.counts.values, b_dates, b.counts.values)
plt.show()

# %%
y = list(set(a_dates))
# Out:
# [datetime.date(2018, 4, 17),
#  datetime.date(2018, 4, 16),
#  datetime.date(2018, 4, 15),
#  datetime.date(2018, 4, 14),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 21),
#  datetime.date(2018, 4, 20),
#  datetime.date(2018, 4, 19)]

# %%
#import matplotlib.pyplot as plt
#plt.plot(a.counts.values)
#plt.set_xticklabels(["1"]*112)
#plt.show()

fig, ax = plt.subplots()
ax.plot(a_dates, a.counts.values)
ax.plot(b_dates, b.counts.values)
# We need to draw the canvas, otherwise the labels won't be positioned and 
# won't have values yet.
fig.canvas.draw()

labels = [a_dates]
[item.get_text() for item in ax.get_xticklabels()]

ax.set_xticklabels(labels)

plt.show()

# %%
len(a.counts.values)
# Out:
# 112

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,10,11])
plt.ylabel('some numbers')
plt.show()

# %%
dates = []
for d in a.created_at.values:
    dates.append(pd.to_datetime(d).date())

# %%
dates
# Out:
# [datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 12),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
#  datetime.date(2018, 4, 13),
# ...
